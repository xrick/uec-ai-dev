# %% [markdown]
# ## 測試項目
# 1. 訓練集中的alarm聲
# 2. 使用pruned and quantized tflite model
# 4. export to cc file

# %%
import os
import sys
import datetime
import shutil
import numpy as np
import tensorflow as tf
# from tensorflow import keras
import zipfile
import wavio
import audioop
import IPython
from common import utils as U
np.set_printoptions(threshold=sys.maxsize)
# Out:
# 2024-07-31 13:36:49.232348: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-31 13:36:49.253592: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-31 13:36:49.253615: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-31 13:36:49.254383: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-31 13:36:49.258539: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-31 13:36:49.625568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from datetime import datetime
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading TFlite Model

# %%
tflite_quant_model_path = "../../trained_models/step_6_QAT_and_Convert2TFLite/multifold/version_1_only_use_fold2/qat_model_uec4C_val93_tr_87_prunInfo_85.0_85.0_DSver15_fold2_20240730131440.tflite";
# Load quantized TFLite model
tflite_interpreter_quant = tf.lite.Interpreter(model_path=tflite_quant_model_path)

# %%
# model.summary()
input_details = tflite_interpreter_quant.get_input_details()
output_details = tflite_interpreter_quant.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])

#resize the input and output
# tflite_interpreter_quant.resize_tensor_input(input_details[0]['index'], (2, 1, 30225, 1))
# tflite_interpreter_quant.resize_tensor_input(output_details[0]['index'], (2, 2))

# input_details = tflite_interpreter_quant.get_input_details()
# output_details = tflite_interpreter_quant.get_output_details()

# print("== Input details ==")
# print("name:", input_details[0]['name'])
# print("shape:", input_details[0]['shape'])
# print("type:", input_details[0]['dtype'])

# print("\n== Output details ==")
# print("name:", output_details[0]['name'])
# print("shape:", output_details[0]['shape'])
# print("type:", output_details[0]['dtype'])

tflite_interpreter_quant.allocate_tensors();
# Out:
# == Input details ==
# name: input.2_te_transform
# shape: [    1     1 20150     1]
# type: <class 'numpy.int8'>
#
# == Output details ==
# name: Xq.1
# shape: [1 4]
# type: <class 'numpy.int8'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### loading dataset from npz format
# 1. ACDNet input length is 30225
# 2. sr is 44100 and 20000
# 3. need to convert 16K to 20000
# ### ACDNet Config Setting
# #### Training Parameters
# 1. opt.batchSize = 64;
# 2. opt.weightDecay = 5e-4;
# 3. opt.momentum = 0.9;
# 4. opt.nEpochs = 2000;
# 5. opt.LR = 0.1;
# 6. opt.schedule = [0.3, 0.6, 0.9];
# 7. opt.warmup = 10;
# #### Basic Net Configuration
# - nClasses = 50
# - nFolds = 5
# - splits = \[i for in range(1, nFolds + 1)\]
# - sr = 20000
# - inputLength = 30225
# <br>ngth = 30225;
# ### How to convert 16K sound to 44.1K with python and sox
#
# if using sox the command is as following: <br />
#     sox old.wav -b 16 new.wav
# if using python you can do as following: <br />
#     import soundfile
#
# data, samplerate = soundfile.read('old.wav
#     <br />)
# soundfile.write('new.wav', data, samplerate, subtype='PCM_1
# 6')

# %%
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def getFileList(srcDir,regex='.*\.wav'):
    results = os.listdir(srcDir)
    out_files = []
    cnt_files = 0
    for file in results:
        if os.path.isdir(os.path.join(srcDir, file)):
            out_files += getFileList(os.path.join(srcDir, file))
        elif re.match(regex, file,  re.I):  # file.startswith(startExtension) or file.endswith(".txt") or file.endswith(endExtension):
            out_files.append(os.path.join(srcDir, file))
            cnt_files = cnt_files + 1
    return out_files

# %%
def quantize_int8(x, axis):
  '''Quantization into int8_t precision, operating on x along axis'''
  scaling_factor_shape = tuple(np.append([len(x)],np.ones(x.ndim - 1, dtype = int)))
  epsilon = 0.000000001
  x_scaling_factor = (np.max(np.abs(x), axis) / 128) + epsilon
  x_scaling_factor = x_scaling_factor.reshape(scaling_factor_shape)
  # x_zero_offset = -0.5 #-0.25 #-0.25
  result = (x / x_scaling_factor) #+ x_zero_offset
  return np.rint(result).astype(np.int8)

# %% [markdown]
# ## sound preprocessing functions

# %%
_inputLen = 20150
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess_debug():
    debug_funcs = []
    debug_funcs += [U.padding( _inputLen// 2),
              U.normalize(32768.0),]
              # U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
    return debug_funcs

def preprocess_setup_help():
    funcs = []
    funcs += [#U.padding(_inputLen//2),
              #U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)
    return sound;

# %%
_funcs = preprocess_setup()
# _debug_funcs = preprocess_debug()

# %% [markdown]
# ### Read Test Wav File

# %%
# print(sounds)
# print(labels)

# %%
# print(sounds_1[0][1].shape)
# print(type(labels_1[0]))

# %%
# sound = np.expand_dims(sound, axis=1)
# sound = np.expand_dims(sound, axis=3)
# print(sound.shape)

# %%
def plot_wav(wavsig):
    plt.plot(wavsig)
    plt.ylabel("Amplitude")
    plt.xlabel("Time")
    plt.show()

# %%
def padding_sig(sig, pad_length):
    sig = np.pad(sig, (0,pad_length), 'constant')
    return sig

# %% [markdown]
# ### Test Alarm

# %%
def test_alarm():
    positive_test_wavs = "../../datasets/CurrentUse/wav_files/src_wavs/positive/alarm/test_val/alarm/"
    p_wav_list = getFileList(positive_test_wavs);
    print(f"total alarm sounds:{len(p_wav_list)} ");
    p_label = 52;
    n_label = 99;
    sounds_1 = [];
    labels_1 = [];
    
    ## sound = preprocess(sound, _funcs)
    for i in p_wav_list:
        sound = wavio.read(i).data.T[0]
        start = sound.nonzero()[0].min();
        end = sound.nonzero()[0].max();
        sound = sound[start: end + 1]
        label = int(p_label);
        if len(sound)> 220500:
            sound = sound[:220500]
        sound = preprocess(sound, _funcs);
        sounds_1.append(sound);
        labels_1.append(label);
    
    print(f"sound testset 1 length: {len(sounds_1)}");
    
    test1_len = len(sounds_1);
    test1_correct_num = 0;
    test1_wrong_num = 0;
    test_wrong_wav_list = [];
    alarm_idx = 0;
    print(f"index explain:\n0:alarm\n1:moaning\n2:help(English)\n3:other sounds\n***************************************************************************");
    for w in range(test1_len): 
        s = sounds_1[w]
        l = labels_1[w]
        s_test = np.expand_dims(s[0], axis=0);
        s_test = np.expand_dims(s_test, axis=1);
        s_test = np.expand_dims(s_test, axis=3);
        s_test = quantize_int8(s_test,axis=-2);
        
        tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
        tflite_interpreter_quant.invoke()
        pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
        pred_idx = np.argmax(pred);
        # print(f"Prediction result shape:{pred.shape}\n");
        print(f"prediction result: {pred}, preediction label:{np.argmax(pred)}, true label: {l}")
        # if l == 52: #positive
        if pred_idx == alarm_idx:
            test1_correct_num += 1;
        else:
            test1_wrong_num += 1;
            test_wrong_wav_list.append(p_wav_list[w]);
    
    print(f"alarm test result is {100*(test1_correct_num/test1_len)}");
    if len(test_wrong_wav_list) > 0:
        print("predict wrong wav files list:")
        for i in test_wrong_wav_list:
            print(f"{i}");

# %%
test_alarm()
# Out:
# total alarm sounds:44
# sound testset 1 length: 44
# index explain:
# 0:alarm
# 1:moaning
# 2:help(English)
# 3:other sounds
# ***************************************************************************
# prediction result: [[-112 -128 -128 -117]], preediction label:0, true label: 52
# prediction result: [[ -81 -128 -128  -93]], preediction label:0, true label: 52
# prediction result: [[-117 -128 -128 -120]], preediction label:0, true label: 52
# prediction result: [[ -97 -128 -128 -106]], preediction label:0, true label: 52
# prediction result: [[ -66 -128 -128  -76]], preediction label:0, true label: 52
# prediction result: [[ -90 -128 -128 -101]], preediction label:0, true label: 52
# prediction result: [[ -87 -128 -128  -98]], preediction label:0, true label: 52
# prediction result: [[ -76 -128 -128  -90]], preediction label:0, true label: 52
# prediction result: [[ -98 -128 -128 -106]], preediction label:0, true label: 52
# prediction result: [[ -77 -128 -128  -87]], preediction label:0, true label: 52
# prediction result: [[-107 -128 -128 -110]], preediction label:0, true label: 52
# prediction result: [[-103 -128 -128 -110]], preediction label:0, true label: 52
# prediction result: [[ -96 -128 -128 -105]], preediction label:0, true label: 52
# prediction result: [[ -97 -128 -128 -106]], preediction label:0, true label: 52
# prediction result: [[ -77 -128 -128  -86]], preediction label:0, true label: 52
# prediction result: [[ -90 -128 -128  -98]], preediction label:0, true label: 52
# prediction result: [[ -85 -128 -128  -96]], preediction label:0, true label: 52
# prediction result: [[ -86 -128 -128  -95]], preediction label:0, true label: 52
# prediction result: [[ -87 -128 -128  -96]], preediction label:0, true label: 52
# prediction result: [[ -91 -128 -128  -98]], preediction label:0, true label: 52
# prediction result: [[ -94 -128 -128 -104]], preediction label:0, true label: 52
# prediction result: [[ -64 -128 -128  -74]], preediction label:0, true label: 52
# prediction result: [[-115 -128 -128 -119]], preediction label:0, true label: 52
# prediction result: [[-107 -128 -128 -111]], preediction label:0, true label: 52
# prediction result: [[-114 -128 -128 -119]], preediction label:0, true label: 52
# prediction result: [[ -99 -128 -128 -104]], preediction label:0, true label: 52
# prediction result: [[ -81 -128 -128  -91]], preediction label:0, true label: 52
# prediction result: [[ -64 -128 -128  -74]], preediction label:0, true label: 52
# prediction result: [[ -99 -128 -128 -107]], preediction label:0, true label: 52
# prediction result: [[ -74 -128 -128  -89]], preediction label:0, true label: 52
# prediction result: [[-102 -128 -128 -109]], preediction label:0, true label: 52
# prediction result: [[ -88 -128 -128  -99]], preediction label:0, true label: 52
# prediction result: [[ -82 -128 -128  -89]], preediction label:0, true label: 52
# prediction result: [[ -92 -128 -128 -100]], preediction label:0, true label: 52
# prediction result: [[-121 -128 -128 -122]], preediction label:0, true label: 52
# prediction result: [[ -82 -128 -128  -93]], preediction label:0, true label: 52
# prediction result: [[ -78 -128 -128  -88]], preediction label:0, true label: 52
# prediction result: [[ -66 -128 -128  -83]], preediction label:0, true label: 52
# prediction result: [[ -95 -128 -128 -104]], preediction label:0, true label: 52
# prediction result: [[ -99 -128 -128 -108]], preediction label:0, true label: 52
# prediction result: [[ -83 -128 -128  -92]], preediction label:0, true label: 52
# prediction result: [[ -73 -128 -128  -82]], preediction label:0, true label: 52
# prediction result: [[ -96 -128 -128 -106]], preediction label:0, true label: 52
# prediction result: [[ -94 -128 -128 -103]], preediction label:0, true label: 52
# alarm test result is 100.0

# %% [markdown]
# ### Test Help(English)

# %%
def endpoint_detection1(src_signal=None, test_seg_len=2000, threshod=500):
    src_signal_len = len(src_signal)
    current_volume_sum = float(0);
    loopnum = (src_signal_len // test_seg_len)-1; #consider drop out the remaining part
    # detect_value_list = [];
    detected_pos = 0;
    for i in range(loopnum):
        start_pos = i*test_seg_len;
        end_pos = (i+1)*test_seg_len;
        test_seg = src_signal[start_pos:end_pos];
        # energy = int(-(np.sqrt(np.mean(test_seg^2))));##-(np.sqrt(np.mean(test_seg**2)));
        energy = -audioop.rms(test_seg, 2)
        energy_bytes = bytes([energy & 0xFF, (energy >> 8) & 0xFF]);# shift energy right 8 bits and put it in high positions
        # print(f"len of test_seg:{len(test_seg)}, bytes seg:{len(energy_bytes * len(test_seg))}")
        debiased_energy = audioop.rms(audioop.add(test_seg, energy_bytes * len(test_seg), 2),2)
        if debiased_energy < threshod:
            detected_pos = end_pos;
        else:
            if debiased_energy > threshod:
                detected_pos = start_pos;
                return detected_pos
        # detect_value_list.append(debiased_energy);
    return detected_pos

# %%
def test_eng_help():
    #settup the preprocessing functions
    _funcs = preprocess_setup_help();
    #set the test english help wav files path
    help_eng_wavs_path = "../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/"
    help_eng_wav_list = getFileList(help_eng_wavs_path);
    all_test_sample_len = len(help_eng_wav_list);
    print(f"Total English Help Speech:{all_test_sample_len}");
    # print("The test wav files are as following:")
    # for i in range(all_test_sample_len):
    #     print(f"{help_eng_wav_list[i]}")
    help_label = 71;
    n_label = 99;
    sounds_help = [];
    labels_help = [];
    print(f"index explain:\n0:alarm\n1:moaning\n2:help(English)\n3:other sounds\n***************************************************************************");
    ## sound = preprocess(sound, _funcs)
    for i in help_eng_wav_list:
        _sound = wavio.read(i).data.T[0]
        start = _sound.nonzero()[0].min();
        end = _sound.nonzero()[0].max();
        _sound = _sound[start: end + 1]
        label = int(help_label);
        if len(_sound)> 220500:
            _sound = _sound[:220500]
        # print("plot _sound before preprocessing");
        # plot_wav(_sound);
        sound = preprocess(_sound, _funcs);
        # print(f"shape of sound:{sound.shape}")
        sounds_help.append(sound);
        labels_help.append(label);
    
    print(f"All English Help Speech Wav Files: {len(help_eng_wav_list)}");
    
    test_correct_num = 0;
    test_wrong_num = 0;
    test_wrong_wav_list = [];
    eng_help_idx = 2;
    print(f"index explain:\n0:alarm\n1:moaning\n2:help(English)\n3:other sounds\n***************************************************************************");
    for w in range(all_test_sample_len): 
        # print(f"current predict wav:{help_eng_wav_list[w]}");
        s = sounds_help[w]
        l = labels_help[w]
        #the following
        s[0].reshape(-1,1);
        s[0] = s[0].T;
        print(f"shape of s[0]:{s[0].shape}")
        #do endpoint detection and modify signal
        silence_endpos = endpoint_detection1(s[0],test_seg_len=200)
        trimed_sig = s[0][silence_endpos:]
        padding_len = len(s[0]) - len(trimed_sig);
        s[0] = padding_sig(trimed_sig, padding_len)
        # print(f"padding_len:{padding_len}")
        # print(f"trimed_sig len:{len(trimed_sig)}")
        
        # print("plot s0:");
        # plot_wav(s[0]);
        # print("plot s1:");
        # plot_wav(s[1]);
        s_test = np.expand_dims(s[0], axis=0);
        s_test = np.expand_dims(s_test, axis=1);
        s_test = np.expand_dims(s_test, axis=3);
        s_test = quantize_int8(s_test,axis=-2);
        
        tflite_interpreter_quant.set_tensor(input_details[0]['index'], s_test);
        tflite_interpreter_quant.invoke()
        pred = tflite_interpreter_quant.get_tensor(output_details[0]['index'])
        pred_idx = np.argmax(pred);
        # print(f"Prediction result shape:{pred.shape}\n");
        print(f"prediction result: {pred}, preediction label:{np.argmax(pred)}, true label: {l}")
        # if l == 52: #positive
        if pred_idx == eng_help_idx:
            test_correct_num += 1;
        else:
            test_wrong_num += 1;
            test_wrong_wav_list.append(help_eng_wav_list[w]);
    
    print(f"english help speech test result is {100*(test_correct_num/all_test_sample_len)}");
    if len(test_wrong_wav_list) > 0:
        print("predict wrong wav files list:")
        for i in test_wrong_wav_list:
            print(f"{i}");

# %%
test_eng_help()
# Out:
# Total English Help Speech:101
# index explain:
# 0:alarm
# 1:moaning
# 2:help(English)
# 3:other sounds
# ***************************************************************************
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# shape of sound:(2, 20150)
# All English Help Speech Wav Files: 101
# index explain:
# 0:alarm
# 1:moaning
# 2:help(English)
# 3:other sounds
# ***************************************************************************
# shape of s[0]:(20150,)
# prediction result: [[-118 -128 -120 -120]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -100 -105]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-113 -128  -99 -106]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-108 -128 -111 -112]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -97 -128 -128 -105]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -96 -128 -125 -104]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -69 -128 -128  -84]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-113 -128 -114 -117]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-120 -128 -122 -120]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -77 -128 -128  -90]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -74 -128 -128  -88]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-106 -128 -113 -111]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-110 -128 -115 -114]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -68 -128 -128  -83]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-122 -128 -127 -119]], preediction label:3, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-111 -128 -114 -115]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-110 -128 -115 -114]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -81 -128 -128  -93]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -67 -128 -128  -83]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -98 -128 -128 -106]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-107 -128 -107 -111]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -88 -128 -128  -98]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-116 -128 -107 -110]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-106 -128 -124 -111]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-110 -128 -126 -115]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-107 -128 -112 -110]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-111 -128 -114 -115]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -97 -128 -128 -104]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-117 -128 -117 -120]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -76 -128 -128  -89]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -78 -128 -128  -90]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-118 -128 -128 -120]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -61 -128 -128  -77]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-109 -128 -109 -113]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-125 -128 -127 -122]], preediction label:3, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -79 -128 -128  -91]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -61 -128 -128  -79]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-115 -128 -128 -118]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -85 -128 -128  -96]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -91 -128 -128 -100]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-105 -128 -105 -110]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -93 -128 -126 -101]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -90 -128 -128  -99]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-100 -128 -128 -108]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -91 -128 -102  -99]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -69 -128 -128  -84]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -113 -117]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-112 -128 -101 -107]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-110 -128 -108 -112]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -88 -128 -128  -97]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128  -94 -101]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -122 -123]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -80 -128 -128  -92]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-116 -128 -116 -119]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-107 -128 -112 -112]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -90 -128 -126  -99]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -60 -128 -128  -78]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -74 -128 -128  -88]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-114 -128 -106 -110]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -110 -114]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128  -97 -106]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -86 -128 -128  -97]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-114 -128 -122 -118]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-111 -128 -106 -111]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-102 -128 -128 -108]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -62 -128 -128  -78]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-115 -128 -112 -115]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-119 -128 -113 -117]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -95 -128 -121 -103]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -99 -128 -112 -105]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128  -78  -89]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -107 -114]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -67 -128 -128  -82]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -83 -128 -128  -95]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -76 -128 -128  -89]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-115 -128 -128 -120]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-108 -128 -113 -112]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-118 -128 -101 -108]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-112 -128 -128 -116]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -72 -128 -128  -86]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128 -105 -111]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -92 -128 -105 -100]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-112 -128 -113 -115]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -93 -128 -128 -101]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -99 -128 -128 -107]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-117 -128 -128 -121]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-116 -128 -128 -119]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -93 -128 -111 -100]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-110 -128 -115 -114]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-118 -128 -110 -113]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-113 -128 -110 -114]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -85 -128 -128  -96]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-128 -128  -96 -106]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -71 -128 -128  -85]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -76 -128 -128  -89]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-111 -128 -121 -115]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -98 -128 -128 -106]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-107 -128 -122 -112]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[ -91 -128  -99  -98]], preediction label:0, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-126 -128 -115 -119]], preediction label:2, true label: 71
# shape of s[0]:(20150,)
# prediction result: [[-126 -128 -107 -114]], preediction label:2, true label: 71
# english help speech test result is 22.772277227722775
# predict wrong wav files list:
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_004_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_032_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_027_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_030_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_010_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_017_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_045_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_054_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_052_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_037_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_007_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_012_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_005_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_017_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_019_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_041_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_021_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_011_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_043_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_003_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_015_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_043_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_016_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_039_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_024_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_002_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_047_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_053_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_006_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_023_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_008_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_004_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_021_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_034_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_022_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_031_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_032_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_036_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_048_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_051_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_033_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_011_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_050_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_049_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_009_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_013_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_036_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_045_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_026_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_055_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_056_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_003_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_035_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_007_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_014_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_014_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_029_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_020_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_001_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_042_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_009_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_037_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_018_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_038_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_046_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_028_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_038_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_005_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_025_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_035_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_025_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_040_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_044_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_019_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_033_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_034_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/man_clear_clip_help_029_71_middle.wav
# ../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/middle/woman_clear_clip_help_010_71_middle.wav

# %%
# scores = model.predict(sound, batch_size=len(sound), verbose=0);
# print(type(scores))
# print(scores.shape)

# for res in scores:
#     max_value = res.max()的
#     max_index = np.argmax(res)
#     print(f"max value:{max_value:.5f} and index is {max_index}")
#     print('\n'.join('{}: {:.5f}'.format(*k) for k in enumerate(res)))
