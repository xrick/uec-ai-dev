# %%
import os
import sys
import numpy as np
import time
# import pyaudio
import wave
import zipfile
import wavio
import random
import asyncio
import IPython
from IPython.display import Audio
from queue import Queue
from threading import Thread
import argparse
import array
import audioop
np.set_printoptions(threshold=sys.maxsize)
# Out:
# /var/folders/m0/l8nfn78n58982dzcy33fh78c0000gn/T/ipykernel_1936/888868886.py:17: DeprecationWarning: 'audioop' is deprecated and slated for removal in Python 3.13
#   import audioop

# %%
# import sounddevice as sd
# import soundfile as sf
# import scipy

# %%
import tensorflow as tf

# %%
import matplotlib.pyplot as plt

# %%
sys.path.append("../../../src/")
sys.path.append("../")
sys.path.append("../../");
# sys.path.append("../../src/SharedLibs/")

# %%
from common import utils as U
from TestSharedLib.bytes import to_bytes, from_bytes, byte_conversion_tests, load_data, load_raw, save_raw, save_scores
from TestSharedLib.constants import quant_support, crops, feature_count
# from Libs.SharedLibs import getFileList;
from SharedLibs.sys_untity import getFileList
# from data_processing_utility import save_wavefile

# %% [markdown]
# ## shared utility codes

# %%
from datetime import datetime
def genDataTimeStr():
    return datetime.today().strftime('%Y-%m-%d %H:%M:%S').replace('-',"").replace(' ',"").replace(':',"");

# %%
def plot_wav(wavsig):
    plt.plot(wavsig)
    plt.ylabel("Amplitude")
    plt.xlabel("Time")
    plt.show()

# %%
"""
np.pad(sig, pad_length//2, 'constant'):
會在sig二端各pad長度為pad_length//2的值，值預設為0
np.pad(sig, (0,pad_length), 'constant')
會在sig的尾端pad值，值預設為0
"""
def padding_sig(sig, pad_length):
    sig = np.pad(sig, (0,pad_length), 'constant')
    return sig

# %%
# model_path = "../../trained_models/step_1_base_train/tflite_model/uec_model_4Classes_20240520150535.tflite";
# model_path = "../../trained_models/step_1_base_train/tflite_model/uec_model_4C_val80tracc89_onesecond_20240621104432.tflite"
model_path = "../../../trained_models/step_1_base_train/tflite_model/uec_model_4C_val80tracc89_onesecond_20240621104432.tflite"
tflite_interpreter = tf.lite.Interpreter(model_path=model_path)

# %%
# model.summary()
input_details = tflite_interpreter.get_input_details()
output_details = tflite_interpreter.get_output_details()

print("== Input details ==")
print("name:", input_details[0]['name'])
print("shape:", input_details[0]['shape'])
print("type:", input_details[0]['dtype'])

print("\n== Output details ==")
print("name:", output_details[0]['name'])
print("shape:", output_details[0]['shape'])
print("type:", output_details[0]['dtype'])
tflite_interpreter.allocate_tensors();
# Out:
# == Input details ==
# name: x.3
# shape: [    1     1 20150     1]
# type: <class 'numpy.float32'>
#
# == Output details ==
# name: 285
# shape: [1 4]
# type: <class 'numpy.float32'>
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.

# %% [markdown]
# ### sound preprocessing codes

# %%
_inputLen = 20150
_nCrops = 2
def preprocess_setup():
    funcs = []
    funcs += [U.padding( _inputLen// 2), #這裏是前後pad _inputLen//2長度的資料
              U.normalize(32768.0),
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return funcs

def preprocess_debug():
    debug_funcs = []
    debug_funcs += [U.padding( _inputLen// 2),
              # U.normalize(32768.0),]
              U.multi_crop(_inputLen, _nCrops)]
              # U.single_crop(_inputLen)]
              # 

    return debug_funcs


def preprocess(sound, funcs):
    for f in funcs:
        sound = f(sound)
    return sound;
    

def padding(pad):
    def f(sound):
        return np.pad(sound, pad, 'constant')

    return f
    

# def random_crop(size):
#     def f(sound):
#         org_size = len(sound)
#         start = random.randint(0, org_size - size)
#         return sound[start: start + size]

#     return f

# %%
# _funcs = preprocess_debug()
_funcs = preprocess_setup()

# %%
def doSoundClassification(sound=None, lblidx=None, channelIdx=0, ifSrc=1):
    start = 0;
    end = 0;
    if ifSrc == 1:
        start = sound.nonzero()[0].min();
        end = sound.nonzero()[0].max();
        sound = sound[start: end + 1];
    # if len(sound)> 220500:
    #     sound = sound[:220500]
    if len(sound)> 20150:
        sound = sound[:20151]
    # sound = np.int16(preprocess(sound, _funcs));
    sound = preprocess(sound, _funcs)
    s_test = np.expand_dims(sound[channelIdx], axis=0)
    s_test = np.expand_dims(s_test, axis=1);
    s_test = np.expand_dims(s_test, axis=3);
    
    tflite_interpreter.set_tensor(input_details[0]['index'], s_test);
    tflite_interpreter.invoke()
    pred = tflite_interpreter.get_tensor(output_details[0]['index'])
    pred_value = pred[0].argmax(axis=0)
    print(f"the largest value index is:{pred_value}");
    print(f"ALL Prediction Result: {pred}");
    # print(f"Prediction result: {pred}, and true label idx: {lblidx}")
    return pred_value

# %%
def endpoint_detection1(src_signal=None, test_seg_len=2000, threshod=500):
    src_signal_len = len(src_signal)
    current_volume_sum = float(0);
    loopnum = (src_signal_len // test_seg_len)-1; #consider drop out the remaining part
    # detect_value_list = [];
    detected_pos = 0;
    for i in range(loopnum):
        start_pos = i*test_seg_len;
        end_pos = (i+1)*test_seg_len;
        test_seg = src_signal[start_pos:end_pos];
        # energy = int(-(np.sqrt(np.mean(test_seg^2))));##-(np.sqrt(np.mean(test_seg**2)));
        energy = -audioop.rms(test_seg, 2)
        energy_bytes = bytes([energy & 0xFF, (energy >> 8) & 0xFF]);# shift energy right 8 bits and put it in high positions
        # print(f"len of test_seg:{len(test_seg)}, bytes seg:{len(energy_bytes * (len(test_seg)//2))}")
        debiased_energy = audioop.rms(audioop.add(test_seg, energy_bytes * len(test_seg), 2),2)
        if debiased_energy < threshod:
            detected_pos = end_pos;
        else:
            if debiased_energy > threshod:
                detected_pos = start_pos;
                return detected_pos
        # detect_value_list.append(debiased_energy);
    return detected_pos

# %%
test_alarm_wav = "../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/alarm_52/155251_p_3.wav"
test_help_eng_wav = "../Eng_Help_Processed_Test_Sounds/test_man_eng_help_001.wav"
test_help_eng_wav2 = "../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/help_eng_71/s2_extend_to_30225_repeat_help/man_clear_clip_help_032_71_sigrep.wav"
head_silence_help_eng_wav1 = "../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/tail/man_clear_clip_help_006_71_tail.wav"
head_silence_wav_file2 = "../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/tail/man_clear_clip_help_008_71_tail.wav";

# %%
IPython.display.display(Audio(head_silence_help_eng_wav1))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
print("original wav waveform")
original_head_silence_sig = wavio.read(head_silence_wav_file2).data.T[0]
plot_wav(original_head_silence_sig)
print(len(original_head_silence_sig))
silence_endpos = endpoint_detection1(original_head_silence_sig,test_seg_len=200)
print(f"silence_endpos:{silence_endpos}")
trimed_sig = original_head_silence_sig[silence_endpos:]
padding_len = len(original_head_silence_sig) - len(trimed_sig)
print(f"padding_len:{padding_len}")
print(f"trimed_sig len:{len(trimed_sig)}")
padded_sig = padding_sig(trimed_sig, padding_len)
plot_wav(padded_sig)
print(len(padded_sig))
# Out:
# original wav waveform
# 30225
# silence_endpos:21200
# padding_len:21200
# trimed_sig len:9025
# 30225

# %% [markdown]
# # Batch Test

# %% [markdown]
# ## tail english help

# %%
def test_help_with_endpoint1(help_eng_wav_dir=None):
    help_eng_list = getFileList(srcDir=help_eng_wav_dir);
    total_files = len(help_eng_list);
    print(f"total files:{total_files}");
    ground_truth = 2;
    src_counter = 0;
    trimmed_counter = 0;
    for f in help_eng_list:
        src_head_silence_sig = wavio.read(f).data.T[0]; #read original wav file
        trim_start_pos = endpoint_detection1(src_head_silence_sig,test_seg_len=200);
        src_head_silence_sig_f32 =  src_head_silence_sig.astype(np.float32);
        trimmed_wav_sig = src_head_silence_sig_f32[trim_start_pos:];
        padding_len = len(src_head_silence_sig_f32) - len(trimmed_wav_sig)
        trimmed_wav_sig = padding_sig(trimmed_wav_sig, padding_len)
        src_output = doSoundClassification(sound=src_head_silence_sig_f32, lblidx=ground_truth, channelIdx=0,ifSrc=1);
        trimmed_output = doSoundClassification(sound=trimmed_wav_sig, lblidx=ground_truth, channelIdx=0, ifSrc=2);
        print(f"ground_truth:{ground_truth}, src_output:{src_output}, trimmed_output:{trimmed_output}");
        if src_counter == ground_truth:
            src_counter+=1;
        if trimmed_output == ground_truth:
            trimmed_counter += 1;
    print(f"original wav files test accuracy:{(src_counter/total_files)*100}%");
    print(f"trimmed wav files test accuracy:{(trimmed_counter/total_files)*100}%")

# %%
help_wav_dir_tail = "../../datasets/CurrentUse/wav_files/src_wavs/positive/help/help_english_71/s2_processed_30225_no_repeat/tail/"
test_help_with_endpoint1(help_eng_wav_dir=help_wav_dir_tail)
# Out:
# total files:101
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.25463009e-05 6.50842703e-05 8.96787643e-01 1.03124745e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[0.00264012 0.55549264 0.126303   0.31556422]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[0.00323691 0.77854896 0.00753057 0.21068351]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.4362110e-05 2.7962931e-04 9.1465497e-01 8.5001074e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.90468070e-05 1.51673985e-05 9.68022048e-01 3.19337808e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.3863354e-04 1.1961455e-03 9.5578229e-01 4.2882849e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.134464e-04 4.436068e-04 8.195816e-01 1.795613e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[5.8937474e-04 7.9755861e-01 2.0717164e-03 1.9978030e-01]]
# the largest value index is:2
# ALL Prediction Result: [[2.3667107e-04 1.0233642e-04 9.2079294e-01 7.8868128e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.4494495e-04 1.5149947e-03 9.3279481e-01 6.5545209e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:2
# ALL Prediction Result: [[0.00101751 0.00224211 0.8583676  0.13837273]]
# the largest value index is:2
# ALL Prediction Result: [[0.00101751 0.00224211 0.8583676  0.13837273]]
# ground_truth:2, src_output:2, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00550122 0.0182501  0.769312   0.2069367 ]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.6196660e-04 6.6342077e-04 8.5003346e-01 1.4904121e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[9.5674250e-07 3.7010784e-06 9.4592994e-01 5.4065391e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.2522144e-05 2.6140258e-05 9.6432954e-01 3.5601839e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.6580717e-04 2.4691764e-03 9.0420723e-01 9.2657834e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.9821986e-05 5.4174408e-05 9.0442753e-01 9.5498480e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00088779 0.00184996 0.86761916 0.12964308]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.3971970e-04 3.6946966e-03 8.9244223e-01 1.0352337e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00137578 0.00817    0.85813713 0.13231707]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[3.6215782e-04 9.1189981e-01 3.5184270e-03 8.4219597e-02]]
# the largest value index is:2
# ALL Prediction Result: [[2.7013401e-04 1.9406602e-03 8.9381665e-01 1.0397253e-01]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.8574543e-04 4.7853537e-04 9.1785777e-01 8.1477948e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.0196125  0.65195346 0.00302332 0.3254107 ]]
# the largest value index is:2
# ALL Prediction Result: [[4.0150495e-04 1.2682497e-03 8.4197509e-01 1.5635507e-01]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.13778326e-04 1.08562876e-04 8.89344931e-01 1.10432826e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.00867665 0.71983534 0.00339612 0.26809198]]
# the largest value index is:3
# ALL Prediction Result: [[0.01138429 0.2775956  0.02923794 0.6817821 ]]
# ground_truth:2, src_output:1, trimmed_output:3
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[7.7971279e-05 1.3057269e-04 9.3486518e-01 6.4926259e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.9089285e-05 6.0775183e-04 9.5012188e-01 4.9201291e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00291628 0.01198281 0.81856704 0.1665338 ]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.1745595e-04 2.5656843e-04 9.2945093e-01 7.0174962e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:2
# ALL Prediction Result: [[5.7260745e-04 8.5132588e-03 8.1062597e-01 1.8028817e-01]]
# the largest value index is:2
# ALL Prediction Result: [[0.00222366 0.04586096 0.6651347  0.28678066]]
# ground_truth:2, src_output:2, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.9463076e-04 5.2563869e-04 9.2586505e-01 7.3414594e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00138423 0.00207692 0.8482189  0.14831987]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.3212440e-04 1.7122458e-03 9.1607624e-01 8.1979416e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.926477e-04 5.605521e-03 9.435185e-01 5.018325e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[5.7879792e-05 3.0449696e-04 9.1049027e-01 8.9147292e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00123565 0.0030956  0.91811454 0.07755411]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:2
# ALL Prediction Result: [[4.0225492e-05 6.5360691e-05 9.4838965e-01 5.1504701e-02]]
# the largest value index is:2
# ALL Prediction Result: [[5.9031729e-05 7.6841148e-05 9.4746995e-01 5.2394215e-02]]
# ground_truth:2, src_output:2, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.8631923e-04 5.5621039e-02 8.7313282e-01 7.0959799e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.0023479e-04 1.6723272e-04 9.4462806e-01 5.4904509e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.9585600e-04 3.0516309e-03 9.2103833e-01 7.5714275e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.00396465 0.7793257  0.00416384 0.21254583]]
# the largest value index is:2
# ALL Prediction Result: [[6.3693093e-05 1.4011888e-04 9.4365191e-01 5.6144193e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.1726330e-04 1.2939132e-04 9.3939590e-01 6.0157415e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00172046 0.26886633 0.59136266 0.13805057]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00192306 0.03292016 0.7528099  0.21234691]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.26196968e-04 2.64926959e-04 8.84015501e-01 1.15093365e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.6572320e-05 1.0053693e-04 9.4350016e-01 5.6332760e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[0.00120999 0.58735937 0.09642428 0.3150064 ]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.5331713e-04 6.1607995e-04 9.2419493e-01 7.4835628e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.4552455e-04 2.4637356e-04 8.7010503e-01 1.2930305e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.1693068e-04 3.5097433e-04 8.9283502e-01 1.0639713e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.2212673e-04 1.2864436e-03 9.4154459e-01 5.6746807e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.0011867  0.7401481  0.00333209 0.2553331 ]]
# the largest value index is:2
# ALL Prediction Result: [[1.9066953e-05 1.4647805e-05 9.4531912e-01 5.4647125e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.2390458e-04 1.3670717e-04 9.5624310e-01 4.3496381e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00449261 0.00582459 0.891685   0.09799774]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.1478581e-04 6.7599309e-03 7.4357682e-01 2.4924846e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[4.8267154e-04 9.1808230e-01 7.1689888e-04 8.0718175e-02]]
# the largest value index is:2
# ALL Prediction Result: [[2.0168553e-04 7.5456902e-04 9.2980361e-01 6.9240145e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00100111 0.00173704 0.8382178  0.15904413]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.6635017e-04 2.1935289e-04 9.6766204e-01 3.1852171e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00644385 0.12039431 0.45356867 0.41959321]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.0220464  0.6115915  0.014238   0.35212407]]
# the largest value index is:2
# ALL Prediction Result: [[1.1201961e-04 1.6377849e-04 9.4046402e-01 5.9260242e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.2607037e-05 1.7877918e-04 8.5811597e-01 1.4168258e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.0402965e-04 3.7393559e-04 9.5369774e-01 4.5724314e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00202251 0.00427125 0.8556754  0.13803081]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[7.6439651e-04 8.6572421e-05 9.4675124e-01 5.2397776e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.3538107e-04 2.6740169e-04 9.5127863e-01 4.8218571e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[7.0301729e-05 4.7515714e-04 9.2143774e-01 7.8016780e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.9790203e-04 3.7687721e-05 9.6676105e-01 3.3003423e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[0.00198133 0.6522432  0.04582497 0.29995057]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.4190696e-04 5.9624517e-04 9.5271403e-01 4.6447791e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00226941 0.0226618  0.8662498  0.10881905]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.8832262e-04 4.5436202e-04 9.0095913e-01 9.8398171e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.0373038e-04 1.8114439e-03 9.4700766e-01 5.1077180e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.7991122e-04 7.1486313e-04 9.4964772e-01 4.9157441e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00097286 0.02921944 0.82693344 0.14287421]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[5.9787073e-04 8.1994658e-05 9.4434518e-01 5.4974992e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00163741 0.03058324 0.7524599  0.21531945]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.16815536e-04 5.93955454e-04 9.37322497e-01 6.19666912e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.5711110e-03 2.9435218e-04 9.4561142e-01 5.2523106e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[7.1431207e-04 2.4170052e-04 9.0618861e-01 9.2855364e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.7950898e-04 5.8694487e-04 9.4306982e-01 5.6163713e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.6000109e-04 2.0341671e-04 9.2718357e-01 7.2453022e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00108623 0.0068644  0.9323263  0.05972296]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.2340327e-04 2.3026635e-04 9.5999467e-01 3.9551739e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.8386414e-05 1.2105084e-04 9.4399101e-01 5.5849515e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.5237300e-05 2.3093744e-05 9.4422400e-01 5.5737618e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.00108028 0.8919333  0.00390877 0.10307761]]
# the largest value index is:2
# ALL Prediction Result: [[8.2640610e-05 1.9942320e-04 8.6492389e-01 1.3479397e-01]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[6.6827389e-04 1.4225354e-03 8.8689810e-01 1.1101102e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:3
# ALL Prediction Result: [[0.01719857 0.21439995 0.34770563 0.4206958 ]]
# ground_truth:2, src_output:3, trimmed_output:3
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[9.2313501e-05 2.3528113e-04 9.2054337e-01 7.9129010e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.6881105e-04 2.7955481e-04 8.9912009e-01 1.0043157e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00097735 0.00276827 0.8480368  0.14821754]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:1
# ALL Prediction Result: [[0.00120449 0.83305186 0.0020864  0.16365722]]
# the largest value index is:2
# ALL Prediction Result: [[1.0728207e-05 3.4264223e-05 9.3406230e-01 6.5892756e-02]]
# ground_truth:2, src_output:1, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[7.1605500e-05 4.5862349e-04 9.2147297e-01 7.7996768e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[2.0102369e-04 1.6062934e-04 8.7986487e-01 1.1977344e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.8784373e-04 1.0405169e-03 8.5734177e-01 1.4142990e-01]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[3.6070912e-04 1.6133826e-03 9.2960358e-01 6.8422273e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[1.9971558e-04 9.4313598e-01 6.9444062e-04 5.5969931e-02]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[9.0012525e-04 6.9619901e-04 9.1131914e-01 8.7084576e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[0.00361587 0.01308101 0.8304619  0.15284124]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[4.3047717e-04 9.5772633e-04 9.0914446e-01 8.9467317e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:1
# ALL Prediction Result: [[1.10218396e-04 9.71203923e-01 4.91672254e-04 2.81941611e-02]]
# ground_truth:2, src_output:3, trimmed_output:1
# the largest value index is:3
# ALL Prediction Result: [[0.06287602 0.3688322  0.07098296 0.49730888]]
# the largest value index is:2
# ALL Prediction Result: [[1.2256450e-04 6.4659707e-04 9.3443167e-01 6.4799175e-02]]
# ground_truth:2, src_output:3, trimmed_output:2
# original wav files test accuracy:0.0%
# trimmed wav files test accuracy:92.07920792079209%

# %% [markdown]
# ## test moaning sounds

# %%
# the following codes are to show the wav files wavforms for selecting test sounds
# val_moaning_dir = "../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/"
# val_moaning_list = getFileList(val_moaning_dir)
# len_of_moaning_list = len(val_moaning_list)
# peek_range = int(len_of_moaning_list)
# for i in range(peek_range):
#     print(val_moaning_list[i])
#     sig = wavio.read(val_moaning_list[i]).data.T[0];
#     plot_wav(sig)
"""
selected moaning sounds for test
having silence in the head
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_48_val_56.wav (fail)
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_47_val_56.wav (work)
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/0V9J_14_2_1_26_0_0_0_delaySpeech0.8_56.wav(work)
no silence in the head
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_49_1_val_56.wav
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_38_val_56.wav
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_39_val_56.wav
has short silence in the head
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_of_pain_31_1.wav
../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_of_pain_28.wav
"""
# Out:
# '\nselected moaning sounds for test\nhaving silence in the head\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_48_val_56.wav\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_47_val_56.wav\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/0V9J_14_2_1_26_0_0_0_delaySpeech0.8_56.wav\nno silence in the head\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_49_1_val_56.wav\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_38_val_56.wav\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/man_moaning_39_val_56.wav\nhas short silence in the head\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_of_pain_31_1.wav\n../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_of_pain_28.wav\n'

# %%
def test_moaning_with_endpoint1(moaning_wav_file=None):
    ground_truth = 1;
    src_counter = 0;
    trimmed_counter = 0;
    src_head_silence_sig = wavio.read(moaning_wav_file).data.T[0]; #read original wav file
    print("original moaning sound wavform")
    IPython.display.display(Audio(src_head_silence_sig,rate=20000))
    plot_wav(src_head_silence_sig)
    trim_start_pos = endpoint_detection1(src_head_silence_sig,test_seg_len=200);
    src_head_silence_sig_f32 =  src_head_silence_sig.astype(np.float32);
    trimmed_wav_sig = src_head_silence_sig_f32[trim_start_pos:];
    padding_len = len(src_head_silence_sig_f32) - len(trimmed_wav_sig)
    trimmed_wav_sig = padding_sig(trimmed_wav_sig, padding_len)
    print("after endpoint detect moaning sound wavform")
    IPython.display.display(Audio(trimmed_wav_sig,rate=20000))
    plot_wav(trimmed_wav_sig)
    print("<<Before endpoint detection result:>>")
    src_output = doSoundClassification(sound=src_head_silence_sig_f32, lblidx=ground_truth, channelIdx=0,ifSrc=1);
    print("======================================================================================")
    print("<<After endpoint detection result:>>")
    trimmed_output = doSoundClassification(sound=trimmed_wav_sig, lblidx=ground_truth, channelIdx=0, ifSrc=2);
    print("======================================================================================")
    print(f"ground_truth:{ground_truth} || original moaning predict:{src_output} || endpoint-detect moaning predict:{trimmed_output}");
    # if src_counter == ground_truth:
    #     src_counter+=1;
    # if trimmed_output == ground_truth:
    #     trimmed_counter += 1;
    # print(f"original wav files test accuracy:{(src_counter/total_files)*100}%");
    # print(f"trimmed wav files test accuracy:{(trimmed_counter/total_files)*100}%")

# %%
test_moaning_file = "../../../datasets/CurrentUse/wav_files/Single_Fold/val/positive/moaning_56/woman_moaning_of_pain_31_1.wav"
test_moaning_with_endpoint1(moaning_wav_file=test_moaning_file)
# Out:
# original moaning sound wavform
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# after endpoint detect moaning sound wavform
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# <<Before endpoint detection result:>>
# the largest value index is:1
# ALL Prediction Result: [[0.00098336 0.8078347  0.00215039 0.18903159]]
# ======================================================================================
# <<After endpoint detection result:>>
# the largest value index is:1
# ALL Prediction Result: [[8.0922138e-05 9.6849740e-01 4.1798124e-04 3.1003702e-02]]
# ======================================================================================
# ground_truth:1 || original moaning predict:1 || endpoint-detect moaning predict:1
