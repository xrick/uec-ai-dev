# %%
import sys;
import os;
import glob;
import math;
import numpy as np;
import glob;
import random;
import time;
import torch;
import torch.optim as optim;
import torch.nn as nn;

sys.path.append(os.getcwd());
sys.path.append(os.path.abspath('../../'));
sys.path.append(os.path.abspath('../../../'));
# sys.path.append(os.path.join(os.getcwd(), 'torch/resources'));
import common.utils as U;
import common.opts as opts;
# import resources.models as models;
import th.resources.calculator as calc;
import common.tlopts as tlopts
# import resources.train_generator as train_generator;
import argparse
from itertools import repeat

# %%
import th.resources.models as models

# %%
from SharedLibs.datestring import genDataTimeStr, getDateStr

# %%
#Reproducibility
seed = 42;
random.seed(seed);
np.random.seed(seed);
torch.manual_seed(seed);
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed);
if torch.backends.mps.is_available():
    torch.mps.manual_seed(seed)
torch.backends.cudnn.deterministic = True;
torch.backends.cudnn.benchmark = False;

# %%
second_pruned_model = "../../../trained_models/step_4_second_stage_pruning/uec_secondPrun_tracc81_pruning_time_2024060614_prunratio90.0/model_second_stage_prun_ratio0.9_20240606140955_upload2.pt"

# %% [markdown]
# ## define the variables opt and set values

# %%
def getOpts():
    parser = argparse.ArgumentParser(description='Transfer Learning for ACDNet');
    parser.add_argument('--netType', default='ACDNetV2',  required=False);
    parser.add_argument('--data', default='trainSet',  required=False);
    parser.add_argument('--dataset', required=False, default='uec_iot', choices=['2']);
    parser.add_argument('--BC', default=True, action='store_true', help='BC learning');
    parser.add_argument('--strongAugment', default=True,  action='store_true', help='Add scale and gain augmentation');
    #在ipynb中，不能使用parser.parse，要改用parser.parse_known_args()
    opt, unknown = parser.parse_known_args();
    return opt
    # opt = parser.parse_args();

# %% [markdown]
# ## Define the Generator

# %%
class TLGenerator():
    #Generates data for Keras
    def __init__(self, samples=None, labels=None, options=None, classes_dict=None):
        random.seed(42);
        #Initialization
        print(f"length of samples:{len(samples)}")
        self.data = [(samples[i], labels[i]) for i in range (0, len(samples))];
        self.opt = options;
        self.batch_size = options.batchSize;
        self.preprocess_funcs = self.preprocess_setup();
        self.mapdict = classes_dict

    def __len__(self):
        #Denotes the number of batches per epoch
        return int(np.floor(len(self.data) / self.batch_size));
        #return len(self.samples);

    def __getitem__(self, batchIndex):
        #Generate one batch of data
        batchX, batchY = self.generate_batch_select_fixed_class(batchIndex);
        batchX = np.expand_dims(batchX, axis=1);
        batchX = np.expand_dims(batchX, axis=3);
        return batchX, batchY

    def generate_batch(self, batchIndex):
        #Generates data containing batch_size samples
        sounds = [];
        labels = [];
        indexes = None;
        for i in range(self.batch_size):
            # Training phase of BC learning
            # Select two training examples
            while True:
                sound1, label1 = self.data[random.randint(0, len(self.data) - 1)]
                sound2, label2 = self.data[random.randint(0, len(self.data) - 1)]
                if label1 != label2:
                    break
            sound1 = self.preprocess(sound1)
            sound2 = self.preprocess(sound2)

            # Mix two examples
            r = np.array(random.random())
            sound = U.mix(sound1, sound2, r, self.opt.sr).astype(np.float32)
            # print(f"sound length after U.mix is {len(sound)}")
            # print(f"nClasses:{self.opt.nClasses}, type of mapdict:{type(self.mapdict)}, type of label1:{type(label1)}")
            eye = np.eye(self.opt.nClasses)
            idx1 = self.mapdict[str(label1)]- 1
            idx2 = self.mapdict[str(label2)] - 1
            label = (eye[idx1] * r + eye[idx2] * (1 - r)).astype(np.float32)
            # label = (eye[label1] * r + eye[label2] * (1 - r)).astype(np.float32)

            #For stronger augmentation
            sound = U.random_gain(6)(sound).astype(np.float32)
            # print(f"sound length after U.random_gain is {len(sound)}")
            sounds.append(sound);
            labels.append(label);

        sounds = np.asarray(sounds);
        labels = np.asarray(labels);
        # print(f"batchIndex is {batchIndex}, total sounds is {len(sounds)}")
        # print(f"labels in generate_batch is:\n{labels}")

        return sounds, labels;

    def generate_batch_select_fixed_class(self, batchIndex):
        #Generates data containing batch_size samples
        sounds = [];
        labels = [];
        indexes = None;
        #two variables recording alarm and moaning sounds count
        alarm_selected = 0;
        moaning_selected = 0;
        help_eng_selected = 0;
        for i in range(self.batch_size):
            # Training phase of BC learning
            # Select two training examples
            while True:
                # print("enter while true")
                sound1, label1 = self.data[random.randint(0, len(self.data) - 1)]
                sound2, label2 = self.data[random.randint(0, len(self.data) - 1)]
                lbl1_int = np.int16(label1);
                lbl2_int = np.int16(label2);
                if (lbl1_int == 52 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int ==52):
                    if (alarm_selected == moaning_selected) and (alarm_selected == help_eng_selected):
                        alarm_selected += 1;
                        break;
                if (lbl1_int == 56 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int == 56):
                    if (moaning_selected < alarm_selected) and (moaning_selected == help_eng_selected):
                        moaning_selected += 1;
                        break;
                if (lbl1_int == 71 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int == 71):
                    if (help_eng_selected < alarm_selected) and (help_eng_selected < moaning_selected):
                        help_eng_selected += 1;
                        break;
            # print(f"escape for loop");
            sound1 = self.preprocess(sound1)
            sound2 = self.preprocess(sound2)

            # Mix two examples
            r = np.array(random.random());
           
            # print(f"r:{r}, lbl1:{label1}, lbl2:{label2}")  
            sound = U.mix(sound1, sound2, r, self.opt.sr).astype(np.float32)
            eye = np.eye(self.opt.nClasses)
            idx1 = self.mapdict[str(label1)]- 1
            idx2 = self.mapdict[str(label2)] - 1
            label = (eye[idx1] * r + eye[idx2] * (1 - r)).astype(np.float32)
            

            #For stronger augmentation
            sound = U.random_gain(6)(sound).astype(np.float32)
            # print(f"sound length after U.random_gain is {len(sound)}")
            sounds.append(sound);
            labels.append(label);

        sounds = np.asarray(sounds);
        labels = np.asarray(labels);
        
        return sounds, labels;

    def preprocess_setup(self):
        funcs = []
        if self.opt.strongAugment:
            funcs += [U.random_scale(1.25)]

        funcs += [U.padding(self.opt.inputLength // 2),
                  U.random_crop(self.opt.inputLength),
                  U.normalize(32768.0)]
        return funcs

    def preprocess(self, sound):
        for f in self.preprocess_funcs:
            sound = f(sound)

        return sound;

# %% [markdown]
# ## Define Trainer

# %%
class ReTrainer:
    def __init__(self, opt=None, classes_dict=None):
        self.opt = opt;
        self.testX = None;
        self.testY = None;
        self.bestAcc = 0.0;
        self.bestAccEpoch = 0;
        self.trainGen = getTrainGen(opt,classes_dict=classes_dict)#train_generator.setup(opt, split);
        # self.opt.trainer = self;
        # self.trainGen = getTrainGen(self.opt, self.opt.splits)#train_generator.setup(self.opt, self.opt.split);
        # self.pretrainedmodelpath = "./resources/pretrained_models/acdnet20_20khz_fold4.h5"

    def Train(self):
        train_start_time = time.time();
        state = torch.load(second_pruned_model, map_location=self.opt.device)
        weights = state['weight']
        config = state['config']
        print(f"config is {config}")
        net = models.GetACDNetModel(input_len=20150, sr=20000, nclass=self.opt.nClasses, channel_config=config).to(self.opt.device);
        net.load_state_dict(weights);
         #show the acdnet structures
        calc.summary(net,(1,1,20150))
        # net = getPrunedModel(pruned_model_path=pruned_acdnet)
        #print networks parameters' require_grade value
        for k_, v_ in net.named_parameters():
            print(f"{k_}:{v_.requires_grad}")
        print('ACDNet model has been prepared for training');

        calc.summary(net, (1,1,self.opt.inputLength));
        # net = net.cuda();
        # training_text = "Re-Training" if self.opt.retrain else "Training from Scratch";
        # print("{} has been started. You will see update after finishing every training epoch and validation".format(training_text));

        lossFunc = torch.nn.KLDivLoss(reduction='batchmean');
        optimizer = optim.SGD(net.parameters(), lr=self.opt.LR, weight_decay=self.opt.weightDecay, momentum=self.opt.momentum, nesterov=True);

        # self.opt.nEpochs = 1957 if self.opt.split == 4 else 2000;
        for epochIdx in range(self.opt.nEpochs):
            epoch_start_time = time.time();
            optimizer.param_groups[0]['lr'] = self.__get_lr(epochIdx+1);
            cur_lr = optimizer.param_groups[0]['lr'];
            running_loss = 0.0;
            running_acc = 0.0;
            n_batches = math.ceil(len(self.trainGen.data)/self.opt.batchSize);
            for batchIdx in range(n_batches):
                # with torch.no_grad():
                x,y = self.trainGen.__getitem__(batchIdx)
                x = torch.tensor(np.moveaxis(x, 3, 1)).to(self.opt.device);
                y = torch.tensor(y).to(self.opt.device);
                # zero the parameter gradients
                optimizer.zero_grad();

                # forward + backward + optimize
                # outputs = net(x);#in office and use cpu
                x = x.type(torch.cuda.FloatTensor) #use apple m2
                outputs = net(x)
               
                res_y = y.argmax(dim=1)
                res_y = res_y.type(torch.cuda.FloatTensor)
                running_acc += ((( outputs.data.argmax(dim=1) == res_y)*1).float().mean()).item();
                y = y.type(torch.cuda.FloatTensor)
                
                loss = lossFunc(outputs.log(), y);
                loss.backward();
                optimizer.step();

                running_loss += loss.item();

            tr_acc = (running_acc / n_batches)*100;
            tr_loss = running_loss / n_batches;

            #Epoch wise validation Validation
            epoch_train_time = time.time() - epoch_start_time;

            net.eval();
            val_acc, val_loss = self.__validate(net, lossFunc);
            #Save best model
            # self.__save_model(val_acc, epochIdx, net);
            # ratio, acc, tr_acc, epochIdx, net
            self.__do_save_model(self.opt.pruningRatio*100, val_acc, tr_acc, epochIdx, net);
            self.__on_epoch_end(epoch_start_time, epoch_train_time, epochIdx, cur_lr, tr_loss, tr_acc, val_loss, val_acc);

            running_loss = 0;
            running_acc = 0;
            net.train();

        total_time_taken = time.time() - train_start_time;
        print("Execution finished in: {}".format(U.to_hms(total_time_taken)));

    def load_test_data(self):
        # data = np.load(os.path.join(self.opt.data, self.opt.dataset, 'test_data_{}khz/fold{}_test4000.npz'.format(self.opt.sr//1000, self.opt.split)), allow_pickle=True);
        data = np.load(self.opt.valData, allow_pickle=True);
        print(f"device is :{self.opt.device}")
        print(f"len of Y:{len(data['y'])}")
        # self.testX = torch.tensor(np.moveaxis(data['x'], 3, 1)).to(self.opt.device);
        dataX = np.moveaxis(data['x'], 3, 1).astype(np.float32);
        self.testX = torch.tensor(dataX).to(self.opt.device);
        self.testY = torch.tensor(data['y']).type(torch.float32).to(self.opt.device);

    def __get_lr(self, epoch):
        divide_epoch = np.array([self.opt.nEpochs * i for i in self.opt.schedule]);
        decay = sum(epoch > divide_epoch);
        if epoch <= self.opt.warmup:
            decay = 1;
        return self.opt.LR * np.power(0.1, decay);

    def __get_batch(self, index):
        x = self.trainX[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        y = self.trainY[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        return x.to(self.opt.device), y.to(self.opt.device);

    def __validate(self, net, lossFunc):
        if self.testX is None:
            self.load_test_data();
        net.eval();
        with torch.no_grad():
            y_pred = None;
            batch_size = len(self.testX);#(self.opt.batchSize//self.opt.nCrops)*self.opt.nCrops;
#             for idx in range(math.ceil(len(self.testX)/batch_size)):
#             for idx in range(len(self.testX)):
#             x = self.testX[idx*batch_size : (idx+1)*batch_size];
            x = self.testX[:];
            x = torch.tensor(x)
            x = x.type(torch.cuda.FloatTensor) # use apple cuda
            scores = net(x);
            y_pred = scores.data if y_pred is None else torch.cat((y_pred, scores.data));
            acc, loss = self.__compute_accuracy(y_pred, self.testY, lossFunc);
        net.train();
        return acc, loss;

    #Calculating average prediction (10 crops) and final accuracy
    def __compute_accuracy(self, y_pred, y_target, lossFunc):
        # print(f"shape of y_pred:{y_pred.shape}");
        # print(f"shape of y_target:{y_target.shape}");
        with torch.no_grad():
            #Reshape to shape theme like each sample comtains 10 samples, calculate mean and find theindices that has highest average value for each sample
            if self.opt.nCrops == 1:
                y_pred = y_pred.argmax(dim=1);
                y_target = y_target.argmax(dim=1);
            else:
                y_pred = (y_pred.reshape(y_pred.shape[0]//self.opt.nCrops, self.opt.nCrops, y_pred.shape[1])).mean(dim=1).argmax(dim=1);
                y_target = (y_target.reshape(y_target.shape[0]//self.opt.nCrops, self.opt.nCrops, y_target.shape[1])).mean(dim=1).argmax(dim=1);
                print(f"after: len of y_pred:{len(y_pred)}, len of y_target:{len(y_target)}")
            y_target = y_target.cuda()
            acc = (((y_pred==y_target)*1).float().mean()*100).item();
            # valLossFunc = torch.nn.KLDivLoss();
            loss = lossFunc(y_pred.float().log(), y_target.float()).item();
            # loss = 0.0;
        return acc, loss;

    def __on_epoch_end(self, start_time, train_time, epochIdx, lr, tr_loss, tr_acc, val_loss, val_acc):
        epoch_time = time.time() - start_time;
        val_time = epoch_time - train_time;
        line = 'SP-{} Epoch: {}/{} | Time: {} (Train {}  Val {}) | Train: LR {}  Loss {:.2f}  Acc {:.2f}% | Val: Loss {:.2f}  Acc(top1) {:.2f}% | HA {:.2f}@{}\n'.format(
            self.opt.splits, epochIdx+1, self.opt.nEpochs, U.to_hms(epoch_time), U.to_hms(train_time), U.to_hms(val_time),
            lr, tr_loss, tr_acc, val_loss, val_acc, self.bestAcc, self.bestAccEpoch);
        # print(line)
        sys.stdout.write(line);
        sys.stdout.flush();

    # def __save_model(self, acc, epochIdx, net):
    #     if acc > self.bestAcc:
    #         self.bestAcc = acc;
    #         self.bestAccEpoch = epochIdx +1;
    #         save_model_name = self.opt.model_name.format(self.opt.pruningRatio*100,acc, epochIdx, genDataTimeStr());
    #         save_model_fullpath = self.opt.saveDir + save_model_name;
    #         print(f"save model to {save_model_fullpath}")
    #         torch.save({'weight':net.state_dict(), 'config':net.ch_config}, save_model_fullpath);

    def __save_model_v2(self, acc, train_acc, epochIdx, net):
        if acc > self.bestAcc and acc > self.opt.first_save_acc:
            self.bestAcc = acc;
            self.bestAccEpoch = epochIdx +1;
            self.__do_save_model(self.opt.pruningRatio*100, acc, train_acc, epochIdx, net);
        else:
            if acc > self.opt.save_val_acc and train_acc > self.opt.save_train_acc: 
                self.__do_save_model(self.opt.pruningRatio*100, acc, train_acc, epochIdx, net);
            else:
                pass

    def __do_save_model(self, ratio, acc, tr_acc, epochIdx, net):
        save_model_name = self.opt.model_name.format(ratio, acc, tr_acc, epochIdx+1, genDataTimeStr());
        save_model_fullpath = self.opt.saveDir + save_model_name;
        print(f"save model to {save_model_fullpath}")
        torch.save({'weight':net.state_dict(), 'config':net.ch_config}, save_model_fullpath);
        # logObj.write(f"save model:{self.opt.model_name}, bestAcc:{self.bestAcc}, valAcc:{acc}, trainAcc:{tr_acc}, record@{epochIdx}-epoch");
        # logObj.write("\n");
        # logObj.flush();

# %%
def getTrainGen(opt=None, split=None, classes_dict=None):
    dataset = np.load(opt.trainData, allow_pickle=True);
    train_sounds = []
    train_labels = []
    train_sounds = dataset['fold{}'.format(1)].item()['sounds']
    train_labels = dataset['fold{}'.format(1)].item()['labels']
    trainGen = TLGenerator(train_sounds, train_labels, opt, classes_dict=classes_dict);
    trainGen.preprocess_setup();
    return trainGen

# %%
""" recording training settings and results
===================================
weight-pruning-ratio:
final acc:93.03
epoch:539
opt.batchSize = 32;
opt.LR = 0.05;
opt.weightDecay = 5e-3;
opt.momentum = 0.04;
opt.nEpochs = 1000;
opt.schedule = [0.15, 0.3, 0.45];
opt.warmup = 10;
====================================================================
###針對二次剪枝後的重訓練，這個設定滿有效果的，要實驗是哪個參數造成的效果。
epoch:293
acc:89.4
tr_acc:76.4
opt.batchSize = 64;
opt.LR = 0.1;
opt.weightDecay = 5e-3;
opt.momentum = 0.5;
opt.nEpochs = 500;
opt.schedule = [0.3, 0.6, 0.9];
====================================================================
dataset version 11
====================================================================
epoch:
acc:
tr_acc:
opt.batchSize = 64;
opt.LR = 0.1;
opt.weightDecay = 5e-4;
opt.momentum = 0.09;
opt.nEpochs = 1600;
opt.schedule = [0.3, 0.6, 0.9];
opt.warmup = 10;
"""
# Out:
# ' recording training settings and results\n===================================\nweight-pruning-ratio:\nfinal acc:93.03\nepoch:539\nopt.batchSize = 32;\nopt.LR = 0.05;\nopt.weightDecay = 5e-3;\nopt.momentum = 0.04;\nopt.nEpochs = 1000;\nopt.schedule = [0.15, 0.3, 0.45];\nopt.warmup = 10;\n====================================================================\n###針對二次剪枝後的重訓練，這個設定滿有效果的，要實驗是哪個參數造成的效果。\nepoch:293\nacc:89.4\ntr_acc:76.4\nopt.batchSize = 64;\nopt.LR = 0.1;\nopt.weightDecay = 5e-3;\nopt.momentum = 0.5;\nopt.nEpochs = 500;\nopt.schedule = [0.3, 0.6, 0.9];\n====================================================================\ndataset version 11\n====================================================================\nepoch:\nacc:\ntr_acc:\nopt.batchSize = 64;\nopt.LR = 0.1;\nopt.weightDecay = 5e-4;\nopt.momentum = 0.09;\nopt.nEpochs = 1600;\nopt.schedule = [0.3, 0.6, 0.9];\nopt.warmup = 10;\n'

# %%
def main():
    map_dict_train = {
        '52':1, #alarm
        '56':2, #moaning
        '71':3,
        '99':4, #other_sounds
    };
    
    opt = getOpts();
    opt.pruningRatio = 0.9
    save_dir = "../../../trained_models/step_5_retrain_after_step_4/retrain_4C_IterPrun_prunratio{}_{}/".format(opt.pruningRatio,getDateStr());
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    print(f"save dir is: {save_dir}");
    opt.current_fold = "fold"
    opt.trainData = "notset";#"../../../../uec_iot_models_datasets/multifold/train/version15_multifold_home_fold1/fold1_train_20240721013720.npz"
    opt.valData = "notset";#"../../../../uec_iot_models_datasets/multifold/val/version15_multifold_home_fold1/final_fold1_val_version15_multifold_home.npz"
    #Leqarning settings
    # opt.first_save_acc = 90.0;
    # opt.save_val_acc = 90.0;
    # opt.save_train_acc = 80.0;
    
    opt.batchSize = 64;
    opt.LR = 0.1;
    opt.weightDecay = 5e-4;
    opt.momentum = 0.9;
    opt.nEpochs = 1600;
    opt.schedule = [0.3, 0.6, 0.9];
    opt.warmup = 10;
    opt.saveDir = save_dir;
    # opt.device="mps";
    if torch.backends.mps.is_available():
        opt.device="mps"; #for apple m2 gpu
    elif torch.cuda.is_available():
        opt.device="cuda:0"; #for nVidia gpu
    else:
        opt.device="cpu"
    print(f"***Use device:{opt.device}");
    # opt.device = torch.device("cuda:0" if  else "cpu");
    #Basic Net Settings
    opt.nClasses = 4
    opt.nFolds = 1;
    opt.splits = [i for i in range(1, opt.nFolds + 1)];
    opt.sr = 20000;
    opt.inputLength = 20150;
    #Test data
    opt.nCrops = 2;
    opt.model_name = "retrained_4Cmodel_ratio{}_vaacc{}_tracc_{}@{}epoch_{}.pt"
    #Starting retraining process
    
    foldlist = ['fold1','fold2','fold3','fold4'];
    train_data_list = [
        "fold1_train_20240721013720.npz",
        "fold2_train_20240721013720.npz",
        "fold3_train_20240721013720.npz",
        "fold4_train_20240721013721.npz"
    ];
    val_data_list = [
        "final_fold1_val_version15_multifold_home.npz",
        "final_fold2_val_version15_multifold_home_20240721023951.npz",
        "final_fold3_val_version15_multifold_home_20240721024246.npz",
        "final_fold4_val_version15_multifold_home_20240721024338.npz"
    ];
    print("start to retrain model after second pruning in other 4-fold datasets")l
    for i in range(len(foldlist)):
        opt.trainData = "../../../../uec_iot_models_datasets/multifold/train/version15_multifold_home_{}/{}".format(foldlist[i],train_data_list[i]);
        opt.valData = "../../../../uec_iot_models_datasets/multifold/val/version15_multifold_home_{}/{}".format(foldlist[i],val_data_list[i]);
        trainer = ReTrainer(opt=opt, classes_dict=map_dict_train);
        trainer.Train();
        del trainer;

# %%
main()
# Out:
# save dir is: ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/
# ***Use device:mps
# length of samples:1205
# config is [8, 32, 9, 17, 19, 20, 20, 20, 20, 16, 19, 4]
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (32, 1, 7553)      1,280    9,667,840
#   BatchNorm2d-5     (32, 1, 7553)     (32, 1, 7553)         64            0
#          ReLu-6     (32, 1, 7553)     (32, 1, 7553)          0      241,696
#     MaxPool2d-7     (32, 1, 7553)      (32, 1, 151)          0      241,600
#       Permute-8      (32, 1, 151)      (1, 32, 151)          0            0
#        Conv2d-9      (1, 32, 151)      (9, 32, 151)         81      391,392
#  BatchNorm2d-10      (9, 32, 151)      (9, 32, 151)         18            0
#         ReLu-11      (9, 32, 151)      (9, 32, 151)          0       43,488
#    MaxPool2d-12      (9, 32, 151)       (9, 16, 75)          0       43,200
#       Conv2d-13       (9, 16, 75)      (17, 16, 75)      1,377    1,652,400
#  BatchNorm2d-14      (17, 16, 75)      (17, 16, 75)         34            0
#         ReLu-15      (17, 16, 75)      (17, 16, 75)          0       20,400
#       Conv2d-16      (17, 16, 75)      (19, 16, 75)      2,907    3,488,400
#  BatchNorm2d-17      (19, 16, 75)      (19, 16, 75)         38            0
#         ReLu-18      (19, 16, 75)      (19, 16, 75)          0       22,800
#    MaxPool2d-19      (19, 16, 75)       (19, 8, 37)          0       22,496
#       Conv2d-20       (19, 8, 37)       (20, 8, 37)      3,420    1,012,320
#  BatchNorm2d-21       (20, 8, 37)       (20, 8, 37)         40            0
#         ReLu-22       (20, 8, 37)       (20, 8, 37)          0        5,920
#       Conv2d-23       (20, 8, 37)       (20, 8, 37)      3,600    1,065,600
#  BatchNorm2d-24       (20, 8, 37)       (20, 8, 37)         40            0
#         ReLu-25       (20, 8, 37)       (20, 8, 37)          0        5,920
#    MaxPool2d-26       (20, 8, 37)       (20, 4, 18)          0        5,760
#       Conv2d-27       (20, 4, 18)       (20, 4, 18)      3,600      259,200
#  BatchNorm2d-28       (20, 4, 18)       (20, 4, 18)         40            0
#         ReLu-29       (20, 4, 18)       (20, 4, 18)          0        1,440
#       Conv2d-30       (20, 4, 18)       (20, 4, 18)      3,600      259,200
#  BatchNorm2d-31       (20, 4, 18)       (20, 4, 18)         40            0
#         ReLu-32       (20, 4, 18)       (20, 4, 18)          0        1,440
#    MaxPool2d-33       (20, 4, 18)        (20, 2, 9)          0        1,440
#       Conv2d-34        (20, 2, 9)        (16, 2, 9)      2,880       51,840
#  BatchNorm2d-35        (16, 2, 9)        (16, 2, 9)         32            0
#         ReLu-36        (16, 2, 9)        (16, 2, 9)          0          288
#       Conv2d-37        (16, 2, 9)        (19, 2, 9)      2,736       49,248
#  BatchNorm2d-38        (19, 2, 9)        (19, 2, 9)         38            0
#         ReLu-39        (19, 2, 9)        (19, 2, 9)          0          342
#    MaxPool2d-40        (19, 2, 9)        (19, 1, 4)          0          304
#       Conv2d-41        (19, 1, 4)         (4, 1, 4)         76          304
#  BatchNorm2d-42         (4, 1, 4)         (4, 1, 4)          8            0
#         ReLu-43         (4, 1, 4)         (4, 1, 4)          0           16
#    AvgPool2d-44         (4, 1, 4)         (4, 1, 1)          0           16
#      Flatten-45         (4, 1, 1)            (1, 4)          0            0
#       Linear-46            (1, 4)            (1, 4)         20           20
#      Softmax-47            (1, 4)            (1, 4)          0            4
# ==============================================================================
# Total Params: 26,057
# Total FLOPs : 19,765,054
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 0.10
# Total size (MB) : 0.21
# ------------------------------------------------------------------------------
#
# sfeb.0.weight:True
# sfeb.1.weight:True
# sfeb.1.bias:True
# sfeb.3.weight:True
# sfeb.4.weight:True
# sfeb.4.bias:True
# tfeb.0.weight:True
# tfeb.1.weight:True
# tfeb.1.bias:True
# tfeb.4.weight:True
# tfeb.5.weight:True
# tfeb.5.bias:True
# tfeb.7.weight:True
# tfeb.8.weight:True
# tfeb.8.bias:True
# tfeb.11.weight:True
# tfeb.12.weight:True
# tfeb.12.bias:True
# tfeb.14.weight:True
# tfeb.15.weight:True
# tfeb.15.bias:True
# tfeb.18.weight:True
# tfeb.19.weight:True
# tfeb.19.bias:True
# tfeb.21.weight:True
# tfeb.22.weight:True
# tfeb.22.bias:True
# tfeb.25.weight:True
# tfeb.26.weight:True
# tfeb.26.bias:True
# tfeb.28.weight:True
# tfeb.29.weight:True
# tfeb.29.bias:True
# tfeb.33.weight:True
# tfeb.34.weight:True
# tfeb.34.bias:True
# tfeb.38.weight:True
# tfeb.38.bias:True
# ACDNet model has been prepared for training
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (32, 1, 7553)      1,280    9,667,840
#   BatchNorm2d-5     (32, 1, 7553)     (32, 1, 7553)         64            0
#          ReLu-6     (32, 1, 7553)     (32, 1, 7553)          0      241,696
#     MaxPool2d-7     (32, 1, 7553)      (32, 1, 151)          0      241,600
#       Permute-8      (32, 1, 151)      (1, 32, 151)          0            0
#        Conv2d-9      (1, 32, 151)      (9, 32, 151)         81      391,392
#  BatchNorm2d-10      (9, 32, 151)      (9, 32, 151)         18            0
#         ReLu-11      (9, 32, 151)      (9, 32, 151)          0       43,488
#    MaxPool2d-12      (9, 32, 151)       (9, 16, 75)          0       43,200
#       Conv2d-13       (9, 16, 75)      (17, 16, 75)      1,377    1,652,400
#  BatchNorm2d-14      (17, 16, 75)      (17, 16, 75)         34            0
#         ReLu-15      (17, 16, 75)      (17, 16, 75)          0       20,400
#       Conv2d-16      (17, 16, 75)      (19, 16, 75)      2,907    3,488,400
#  BatchNorm2d-17      (19, 16, 75)      (19, 16, 75)         38            0
#         ReLu-18      (19, 16, 75)      (19, 16, 75)          0       22,800
#    MaxPool2d-19      (19, 16, 75)       (19, 8, 37)          0       22,496
#       Conv2d-20       (19, 8, 37)       (20, 8, 37)      3,420    1,012,320
#  BatchNorm2d-21       (20, 8, 37)       (20, 8, 37)         40            0
#         ReLu-22       (20, 8, 37)       (20, 8, 37)          0        5,920
#       Conv2d-23       (20, 8, 37)       (20, 8, 37)      3,600    1,065,600
#  BatchNorm2d-24       (20, 8, 37)       (20, 8, 37)         40            0
#         ReLu-25       (20, 8, 37)       (20, 8, 37)          0        5,920
#    MaxPool2d-26       (20, 8, 37)       (20, 4, 18)          0        5,760
#       Conv2d-27       (20, 4, 18)       (20, 4, 18)      3,600      259,200
#  BatchNorm2d-28       (20, 4, 18)       (20, 4, 18)         40            0
#         ReLu-29       (20, 4, 18)       (20, 4, 18)          0        1,440
#       Conv2d-30       (20, 4, 18)       (20, 4, 18)      3,600      259,200
#  BatchNorm2d-31       (20, 4, 18)       (20, 4, 18)         40            0
#         ReLu-32       (20, 4, 18)       (20, 4, 18)          0        1,440
#    MaxPool2d-33       (20, 4, 18)        (20, 2, 9)          0        1,440
#       Conv2d-34        (20, 2, 9)        (16, 2, 9)      2,880       51,840
#  BatchNorm2d-35        (16, 2, 9)        (16, 2, 9)         32            0
#         ReLu-36        (16, 2, 9)        (16, 2, 9)          0          288
#       Conv2d-37        (16, 2, 9)        (19, 2, 9)      2,736       49,248
#  BatchNorm2d-38        (19, 2, 9)        (19, 2, 9)         38            0
#         ReLu-39        (19, 2, 9)        (19, 2, 9)          0          342
#    MaxPool2d-40        (19, 2, 9)        (19, 1, 4)          0          304
#       Conv2d-41        (19, 1, 4)         (4, 1, 4)         76          304
#  BatchNorm2d-42         (4, 1, 4)         (4, 1, 4)          8            0
#         ReLu-43         (4, 1, 4)         (4, 1, 4)          0           16
#    AvgPool2d-44         (4, 1, 4)         (4, 1, 1)          0           16
#      Flatten-45         (4, 1, 1)            (1, 4)          0            0
#       Linear-46            (1, 4)            (1, 4)         20           20
#      Softmax-47            (1, 4)            (1, 4)          0            4
# ==============================================================================
# Total Params: 26,057
# Total FLOPs : 19,765,054
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 0.10
# Total size (MB) : 0.21
# ------------------------------------------------------------------------------
#
# device is :mps
# len of Y:828
# /var/folders/m0/l8nfn78n58982dzcy33fh78c0000gn/T/ipykernel_10244/2278684823.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc31.1594181060791_tracc_32.8125@1epoch_20240607011935.pt
# SP-[1] Epoch: 1/1600 | Time: 0m16s (Train 0m12s  Val 0m03s) | Train: LR 0.010000000000000002  Loss 1.28  Acc 32.81% | Val: Loss nan  Acc(top1) 31.16% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc28.260868072509766_tracc_33.55263157894737@2epoch_20240607011950.pt
# SP-[1] Epoch: 2/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.89  Acc 33.55% | Val: Loss nan  Acc(top1) 28.26% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc35.7487907409668_tracc_37.993421052631575@3epoch_20240607012005.pt
# SP-[1] Epoch: 3/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.84  Acc 37.99% | Val: Loss nan  Acc(top1) 35.75% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc60.386474609375_tracc_40.78947368421053@4epoch_20240607012019.pt
# SP-[1] Epoch: 4/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.80  Acc 40.79% | Val: Loss nan  Acc(top1) 60.39% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc62.07729721069336_tracc_40.87171052631579@5epoch_20240607012034.pt
# SP-[1] Epoch: 5/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.80  Acc 40.87% | Val: Loss nan  Acc(top1) 62.08% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc35.02415466308594_tracc_39.80263157894737@6epoch_20240607012049.pt
# SP-[1] Epoch: 6/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.80  Acc 39.80% | Val: Loss nan  Acc(top1) 35.02% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc64.49275970458984_tracc_44.40789473684211@7epoch_20240607012104.pt
# SP-[1] Epoch: 7/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.78  Acc 44.41% | Val: Loss nan  Acc(top1) 64.49% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc41.78744125366211_tracc_40.78947368421053@8epoch_20240607012118.pt
# SP-[1] Epoch: 8/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.78  Acc 40.79% | Val: Loss nan  Acc(top1) 41.79% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc66.66667175292969_tracc_44.243421052631575@9epoch_20240607012133.pt
# SP-[1] Epoch: 9/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.78  Acc 44.24% | Val: Loss nan  Acc(top1) 66.67% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc68.1159439086914_tracc_43.99671052631579@10epoch_20240607012148.pt
# SP-[1] Epoch: 10/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.76  Acc 44.00% | Val: Loss nan  Acc(top1) 68.12% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc54.10627746582031_tracc_34.29276315789473@11epoch_20240607012203.pt
# SP-[1] Epoch: 11/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.85  Acc 34.29% | Val: Loss nan  Acc(top1) 54.11% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc67.87439727783203_tracc_42.598684210526315@12epoch_20240607012218.pt
# SP-[1] Epoch: 12/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.79  Acc 42.60% | Val: Loss nan  Acc(top1) 67.87% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc42.51207733154297_tracc_46.54605263157895@13epoch_20240607012233.pt
# SP-[1] Epoch: 13/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.76  Acc 46.55% | Val: Loss nan  Acc(top1) 42.51% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc68.59902954101562_tracc_43.75@14epoch_20240607012249.pt
# SP-[1] Epoch: 14/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.75  Acc 43.75% | Val: Loss nan  Acc(top1) 68.60% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc44.68598937988281_tracc_44.65460526315789@15epoch_20240607012304.pt
# SP-[1] Epoch: 15/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.75  Acc 44.65% | Val: Loss nan  Acc(top1) 44.69% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc53.38164138793945_tracc_47.69736842105263@16epoch_20240607012319.pt
# SP-[1] Epoch: 16/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.72  Acc 47.70% | Val: Loss nan  Acc(top1) 53.38% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc72.22222137451172_tracc_53.04276315789473@17epoch_20240607012334.pt
# SP-[1] Epoch: 17/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.66  Acc 53.04% | Val: Loss nan  Acc(top1) 72.22% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc69.56521606445312_tracc_53.7828947368421@18epoch_20240607012349.pt
# SP-[1] Epoch: 18/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.66  Acc 53.78% | Val: Loss nan  Acc(top1) 69.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc77.5362319946289_tracc_54.6875@19epoch_20240607012403.pt
# SP-[1] Epoch: 19/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.66  Acc 54.69% | Val: Loss nan  Acc(top1) 77.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc75.12077331542969_tracc_55.50986842105263@20epoch_20240607012418.pt
# SP-[1] Epoch: 20/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.65  Acc 55.51% | Val: Loss nan  Acc(top1) 75.12% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc62.560386657714844_tracc_56.74342105263158@21epoch_20240607012433.pt
# SP-[1] Epoch: 21/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.63  Acc 56.74% | Val: Loss nan  Acc(top1) 62.56% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc76.81159210205078_tracc_57.976973684210535@22epoch_20240607012449.pt
# SP-[1] Epoch: 22/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.64  Acc 57.98% | Val: Loss nan  Acc(top1) 76.81% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc69.32366943359375_tracc_59.12828947368421@23epoch_20240607012504.pt
# SP-[1] Epoch: 23/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.64  Acc 59.13% | Val: Loss nan  Acc(top1) 69.32% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc76.81159210205078_tracc_59.62171052631579@24epoch_20240607012520.pt
# SP-[1] Epoch: 24/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.62  Acc 59.62% | Val: Loss nan  Acc(top1) 76.81% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.98550415039062_tracc_58.4703947368421@25epoch_20240607012535.pt
# SP-[1] Epoch: 25/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.62  Acc 58.47% | Val: Loss nan  Acc(top1) 78.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.01931762695312_tracc_61.5953947368421@26epoch_20240607012550.pt
# SP-[1] Epoch: 26/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.61  Acc 61.60% | Val: Loss nan  Acc(top1) 78.02% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc70.77294921875_tracc_60.85526315789473@27epoch_20240607012604.pt
# SP-[1] Epoch: 27/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.86% | Val: Loss nan  Acc(top1) 70.77% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc61.594200134277344_tracc_61.75986842105263@28epoch_20240607012619.pt
# SP-[1] Epoch: 28/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.58  Acc 61.76% | Val: Loss nan  Acc(top1) 61.59% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc57.971012115478516_tracc_60.19736842105263@29epoch_20240607012634.pt
# SP-[1] Epoch: 29/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.20% | Val: Loss nan  Acc(top1) 57.97% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.26087188720703_tracc_61.92434210526315@30epoch_20240607012649.pt
# SP-[1] Epoch: 30/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 61.92% | Val: Loss nan  Acc(top1) 78.26% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc72.70531463623047_tracc_61.01973684210527@31epoch_20240607012703.pt
# SP-[1] Epoch: 31/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.60  Acc 61.02% | Val: Loss nan  Acc(top1) 72.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc68.84058380126953_tracc_62.5@32epoch_20240607012718.pt
# SP-[1] Epoch: 32/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.57  Acc 62.50% | Val: Loss nan  Acc(top1) 68.84% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc53.140098571777344_tracc_61.18421052631579@33epoch_20240607012733.pt
# SP-[1] Epoch: 33/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 61.18% | Val: Loss nan  Acc(top1) 53.14% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc71.01449584960938_tracc_63.98026315789473@34epoch_20240607012748.pt
# SP-[1] Epoch: 34/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.57  Acc 63.98% | Val: Loss nan  Acc(top1) 71.01% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc80.43478393554688_tracc_64.14473684210526@35epoch_20240607012802.pt
# SP-[1] Epoch: 35/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 64.14% | Val: Loss nan  Acc(top1) 80.43% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc77.05313873291016_tracc_63.48684210526315@36epoch_20240607012817.pt
# SP-[1] Epoch: 36/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 63.49% | Val: Loss nan  Acc(top1) 77.05% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.8164291381836_tracc_63.48684210526315@37epoch_20240607012832.pt
# SP-[1] Epoch: 37/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 63.49% | Val: Loss nan  Acc(top1) 83.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.98550415039062_tracc_61.348684210526315@38epoch_20240607012847.pt
# SP-[1] Epoch: 38/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.58  Acc 61.35% | Val: Loss nan  Acc(top1) 78.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc82.60869598388672_tracc_65.625@39epoch_20240607012901.pt
# SP-[1] Epoch: 39/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 65.62% | Val: Loss nan  Acc(top1) 82.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc74.63768005371094_tracc_65.37828947368422@40epoch_20240607012916.pt
# SP-[1] Epoch: 40/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 65.38% | Val: Loss nan  Acc(top1) 74.64% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.8164291381836_tracc_66.94078947368422@41epoch_20240607012931.pt
# SP-[1] Epoch: 41/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 66.94% | Val: Loss nan  Acc(top1) 83.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.5024185180664_tracc_62.99342105263158@42epoch_20240607012946.pt
# SP-[1] Epoch: 42/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 62.99% | Val: Loss nan  Acc(top1) 78.50% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.98550415039062_tracc_65.13157894736842@43epoch_20240607013000.pt
# SP-[1] Epoch: 43/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 65.13% | Val: Loss nan  Acc(top1) 78.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc82.60869598388672_tracc_63.4046052631579@44epoch_20240607013015.pt
# SP-[1] Epoch: 44/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 63.40% | Val: Loss nan  Acc(top1) 82.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc70.5313949584961_tracc_64.0625@45epoch_20240607013030.pt
# SP-[1] Epoch: 45/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 64.06% | Val: Loss nan  Acc(top1) 70.53% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc60.386474609375_tracc_63.24013157894737@46epoch_20240607013045.pt
# SP-[1] Epoch: 46/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 63.24% | Val: Loss nan  Acc(top1) 60.39% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.78260803222656_tracc_65.70723684210526@47epoch_20240607013059.pt
# SP-[1] Epoch: 47/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 65.71% | Val: Loss nan  Acc(top1) 84.78% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc68.59902954101562_tracc_65.95394736842105@48epoch_20240607013114.pt
# SP-[1] Epoch: 48/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 65.95% | Val: Loss nan  Acc(top1) 68.60% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc87.43961334228516_tracc_66.5296052631579@49epoch_20240607013129.pt
# SP-[1] Epoch: 49/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 66.53% | Val: Loss nan  Acc(top1) 87.44% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc79.95169067382812_tracc_68.66776315789474@50epoch_20240607013143.pt
# SP-[1] Epoch: 50/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.67% | Val: Loss nan  Acc(top1) 79.95% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.05796813964844_tracc_67.10526315789474@51epoch_20240607013158.pt
# SP-[1] Epoch: 51/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 67.11% | Val: Loss nan  Acc(top1) 84.06% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc58.45410919189453_tracc_68.25657894736842@52epoch_20240607013213.pt
# SP-[1] Epoch: 52/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 68.26% | Val: Loss nan  Acc(top1) 58.45% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.05796813964844_tracc_66.2828947368421@53epoch_20240607013228.pt
# SP-[1] Epoch: 53/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 66.28% | Val: Loss nan  Acc(top1) 84.06% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc80.91787719726562_tracc_65.95394736842105@54epoch_20240607013242.pt
# SP-[1] Epoch: 54/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 65.95% | Val: Loss nan  Acc(top1) 80.92% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.8164291381836_tracc_68.50328947368422@55epoch_20240607013257.pt
# SP-[1] Epoch: 55/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 68.50% | Val: Loss nan  Acc(top1) 83.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc79.4686050415039_tracc_67.43421052631578@56epoch_20240607013312.pt
# SP-[1] Epoch: 56/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 67.43% | Val: Loss nan  Acc(top1) 79.47% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc87.68115997314453_tracc_66.11842105263158@57epoch_20240607013326.pt
# SP-[1] Epoch: 57/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 66.12% | Val: Loss nan  Acc(top1) 87.68% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc79.71014404296875_tracc_65.13157894736842@58epoch_20240607013341.pt
# SP-[1] Epoch: 58/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 65.13% | Val: Loss nan  Acc(top1) 79.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.33332824707031_tracc_68.17434210526315@59epoch_20240607013356.pt
# SP-[1] Epoch: 59/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.17% | Val: Loss nan  Acc(top1) 83.33% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc86.23188018798828_tracc_66.61184210526315@60epoch_20240607013411.pt
# SP-[1] Epoch: 60/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 66.61% | Val: Loss nan  Acc(top1) 86.23% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc81.8840560913086_tracc_68.00986842105263@61epoch_20240607013426.pt
# SP-[1] Epoch: 61/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.01% | Val: Loss nan  Acc(top1) 81.88% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.57488250732422_tracc_69.24342105263158@62epoch_20240607013440.pt
# SP-[1] Epoch: 62/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 69.24% | Val: Loss nan  Acc(top1) 83.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.54106140136719_tracc_66.61184210526315@63epoch_20240607013455.pt
# SP-[1] Epoch: 63/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 66.61% | Val: Loss nan  Acc(top1) 84.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.29951477050781_tracc_67.92763157894737@64epoch_20240607013510.pt
# SP-[1] Epoch: 64/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.93% | Val: Loss nan  Acc(top1) 84.30% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.57488250732422_tracc_69.16118421052632@65epoch_20240607013525.pt
# SP-[1] Epoch: 65/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 69.16% | Val: Loss nan  Acc(top1) 83.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc75.12077331542969_tracc_67.02302631578947@66epoch_20240607013539.pt
# SP-[1] Epoch: 66/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.02% | Val: Loss nan  Acc(top1) 75.12% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc86.71497344970703_tracc_66.5296052631579@67epoch_20240607013554.pt
# SP-[1] Epoch: 67/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 66.53% | Val: Loss nan  Acc(top1) 86.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc83.8164291381836_tracc_69.49013157894737@68epoch_20240607013608.pt
# SP-[1] Epoch: 68/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 69.49% | Val: Loss nan  Acc(top1) 83.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.5024185180664_tracc_70.64144736842105@69epoch_20240607013623.pt
# SP-[1] Epoch: 69/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 70.64% | Val: Loss nan  Acc(top1) 78.50% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc85.74879455566406_tracc_68.17434210526315@70epoch_20240607013637.pt
# SP-[1] Epoch: 70/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.17% | Val: Loss nan  Acc(top1) 85.75% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc75.84540557861328_tracc_67.43421052631578@71epoch_20240607013652.pt
# SP-[1] Epoch: 71/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 67.43% | Val: Loss nan  Acc(top1) 75.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc78.5024185180664_tracc_67.35197368421053@72epoch_20240607013706.pt
# SP-[1] Epoch: 72/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 67.35% | Val: Loss nan  Acc(top1) 78.50% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc72.22222137451172_tracc_67.10526315789474@73epoch_20240607013721.pt
# SP-[1] Epoch: 73/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.11% | Val: Loss nan  Acc(top1) 72.22% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc86.71497344970703_tracc_70.55921052631578@74epoch_20240607013735.pt
# SP-[1] Epoch: 74/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 70.56% | Val: Loss nan  Acc(top1) 86.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc70.77294921875_tracc_69.6546052631579@75epoch_20240607013750.pt
# SP-[1] Epoch: 75/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 69.65% | Val: Loss nan  Acc(top1) 70.77% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc79.95169067382812_tracc_69.81907894736842@76epoch_20240607013804.pt
# SP-[1] Epoch: 76/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 69.82% | Val: Loss nan  Acc(top1) 79.95% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc73.91304016113281_tracc_67.8453947368421@77epoch_20240607013819.pt
# SP-[1] Epoch: 77/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.85% | Val: Loss nan  Acc(top1) 73.91% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc84.05796813964844_tracc_67.51644736842105@78epoch_20240607013833.pt
# ...
# SP-[1] Epoch: 557/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 78.21% | Val: Loss nan  Acc(top1) 92.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_81.00328947368422@558epoch_20240607033521.pt
# SP-[1] Epoch: 558/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 81.00% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_81.33223684210526@559epoch_20240607033535.pt
# SP-[1] Epoch: 559/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 81.33% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.78743743896484_tracc_81.57894736842105@560epoch_20240607033550.pt
# SP-[1] Epoch: 560/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 81.58% | Val: Loss nan  Acc(top1) 91.79% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.02898406982422_tracc_78.04276315789474@561epoch_20240607033604.pt
# SP-[1] Epoch: 561/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 78.04% | Val: Loss nan  Acc(top1) 92.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.82125091552734_tracc_78.7828947368421@562epoch_20240607033619.pt
# SP-[1] Epoch: 562/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.31  Acc 78.78% | Val: Loss nan  Acc(top1) 90.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.5797119140625_tracc_80.50986842105263@563epoch_20240607033634.pt
# SP-[1] Epoch: 563/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 80.51% | Val: Loss nan  Acc(top1) 90.58% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.5797119140625_tracc_80.67434210526315@564epoch_20240607033648.pt
# SP-[1] Epoch: 564/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 80.67% | Val: Loss nan  Acc(top1) 90.58% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc89.85507202148438_tracc_80.5921052631579@565epoch_20240607033703.pt
# SP-[1] Epoch: 565/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 80.59% | Val: Loss nan  Acc(top1) 89.86% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.30435180664062_tracc_80.50986842105263@566epoch_20240607033717.pt
# SP-[1] Epoch: 566/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 80.51% | Val: Loss nan  Acc(top1) 91.30% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.5797119140625_tracc_80.01644736842105@567epoch_20240607033732.pt
# SP-[1] Epoch: 567/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 80.02% | Val: Loss nan  Acc(top1) 90.58% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.2705307006836_tracc_78.20723684210526@568epoch_20240607033746.pt
# SP-[1] Epoch: 568/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 78.21% | Val: Loss nan  Acc(top1) 92.27% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_80.09868421052632@569epoch_20240607033801.pt
# SP-[1] Epoch: 569/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 80.10% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.09661865234375_tracc_80.83881578947368@570epoch_20240607033815.pt
# SP-[1] Epoch: 570/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 80.84% | Val: Loss nan  Acc(top1) 90.10% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_81.99013157894737@571epoch_20240607033830.pt
# SP-[1] Epoch: 571/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 81.99% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc89.85507202148438_tracc_82.8125@572epoch_20240607033845.pt
# SP-[1] Epoch: 572/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 82.81% | Val: Loss nan  Acc(top1) 89.86% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.2705307006836_tracc_80.09868421052632@573epoch_20240607033859.pt
# SP-[1] Epoch: 573/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 80.10% | Val: Loss nan  Acc(top1) 92.27% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_79.93421052631578@574epoch_20240607033914.pt
# SP-[1] Epoch: 574/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 79.93% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.51207733154297_tracc_79.11184210526315@575epoch_20240607033928.pt
# SP-[1] Epoch: 575/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 79.11% | Val: Loss nan  Acc(top1) 92.51% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.51207733154297_tracc_81.00328947368422@576epoch_20240607033943.pt
# SP-[1] Epoch: 576/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 81.00% | Val: Loss nan  Acc(top1) 92.51% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc89.613525390625_tracc_80.50986842105263@577epoch_20240607033958.pt
# SP-[1] Epoch: 577/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 80.51% | Val: Loss nan  Acc(top1) 89.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.2705307006836_tracc_78.70065789473685@578epoch_20240607034012.pt
# SP-[1] Epoch: 578/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 78.70% | Val: Loss nan  Acc(top1) 92.27% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.54589080810547_tracc_80.83881578947368@579epoch_20240607034027.pt
# SP-[1] Epoch: 579/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 80.84% | Val: Loss nan  Acc(top1) 91.55% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.30435180664062_tracc_81.16776315789474@580epoch_20240607034041.pt
# SP-[1] Epoch: 580/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 81.17% | Val: Loss nan  Acc(top1) 91.30% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.06280517578125_tracc_80.75657894736842@581epoch_20240607034056.pt
# SP-[1] Epoch: 581/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.28  Acc 80.76% | Val: Loss nan  Acc(top1) 91.06% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc91.06280517578125_tracc_79.19407894736842@582epoch_20240607034110.pt
# SP-[1] Epoch: 582/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.31  Acc 79.19% | Val: Loss nan  Acc(top1) 91.06% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.82125091552734_tracc_79.60526315789474@583epoch_20240607034125.pt
# SP-[1] Epoch: 583/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 79.61% | Val: Loss nan  Acc(top1) 90.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.02898406982422_tracc_81.16776315789474@584epoch_20240607034139.pt
# SP-[1] Epoch: 584/1600 | Time: 0m14s (Train 0m12s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.29  Acc 81.17% | Val: Loss nan  Acc(top1) 92.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.02898406982422_tracc_80.42763157894737@585epoch_20240607034154.pt
# SP-[1] Epoch: 585/1600 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.27  Acc 80.43% | Val: Loss nan  Acc(top1) 92.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc92.02898406982422_tracc_77.96052631578947@586epoch_20240607034209.pt
# SP-[1] Epoch: 586/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 77.96% | Val: Loss nan  Acc(top1) 92.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.82125091552734_tracc_80.42763157894737@587epoch_20240607034225.pt
# SP-[1] Epoch: 587/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 80.43% | Val: Loss nan  Acc(top1) 90.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.9_2024060701/retrained_4Cmodel_ratio90.0_vaacc90.82125091552734_tracc_77.54934210526315@588epoch_20240607034240.pt
# SP-[1] Epoch: 588/1600 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.30  Acc 77.55% | Val: Loss nan  Acc(top1) 90.82% | HA 0.00@0
