# %%
import sys;
import os;
import glob;
import math;
import numpy as np;
import glob;
import random;
import time;
import torch;
import torch.optim as optim;
import torch.nn as nn;

sys.path.append(os.getcwd());
sys.path.append(os.path.abspath('../../'));
sys.path.append(os.path.abspath('../../../'));
# sys.path.append(os.path.join(os.getcwd(), 'torch/resources'));
import common.utils as U;
import common.opts as opts;
# import resources.models as models;
import th.resources.calculator as calc;
import common.tlopts as tlopts
# import resources.train_generator as train_generator;
import argparse
from itertools import repeat

# %%
import th.resources.models as models

# %%
from SharedLibs.datestring import genDataTimeStr, getDateStr

# %%
#Reproducibility
seed = 42;
random.seed(seed);
np.random.seed(seed);
torch.manual_seed(seed);
if torch.cuda.is_available():
    torch.cuda.manual_seed(seed);
torch.backends.cudnn.deterministic = True;
torch.backends.cudnn.benchmark = False;

# %%
second_pruned_model = "../../../trained_models/step_4_second_stage_pruning/valacc_95.34_tracc89_pruning_time_2024060409_prunratio85.0/model_second_stage_prun_ratio0.85_20240604094952.pt"

# %% [markdown]
# ## define the variables opt and set values

# %%
def getOpts():
    parser = argparse.ArgumentParser(description='Transfer Learning for ACDNet');
    parser.add_argument('--netType', default='ACDNetV2',  required=False);
    parser.add_argument('--data', default='trainSet',  required=False);
    parser.add_argument('--dataset', required=False, default='uec_iot', choices=['2']);
    parser.add_argument('--BC', default=True, action='store_true', help='BC learning');
    parser.add_argument('--strongAugment', default=True,  action='store_true', help='Add scale and gain augmentation');
    #在ipynb中，不能使用parser.parse，要改用parser.parse_known_args()
    opt, unknown = parser.parse_known_args();
    return opt
    # opt = parser.parse_args();

# %% [markdown]
# ## Define the Generator

# %%
class TLGenerator():
    #Generates data for Keras
    def __init__(self, samples=None, labels=None, options=None, classes_dict=None):
        random.seed(42);
        #Initialization
        print(f"length of samples:{len(samples)}")
        self.data = [(samples[i], labels[i]) for i in range (0, len(samples))];
        self.opt = options;
        self.batch_size = options.batchSize;
        self.preprocess_funcs = self.preprocess_setup();
        self.mapdict = classes_dict

    def __len__(self):
        #Denotes the number of batches per epoch
        return int(np.floor(len(self.data) / self.batch_size));
        #return len(self.samples);

    def __getitem__(self, batchIndex):
        #Generate one batch of data
        batchX, batchY = self.generate_batch(batchIndex);
        # batchX, batchY = self.generate_batch_select_fixed_class(batchIndex);
        batchX = np.expand_dims(batchX, axis=1);
        batchX = np.expand_dims(batchX, axis=3);
        return batchX, batchY

    def generate_batch(self, batchIndex):
        #Generates data containing batch_size samples
        sounds = [];
        labels = [];
        indexes = None;
        for i in range(self.batch_size):
            # Training phase of BC learning
            # Select two training examples
            while True:
                sound1, label1 = self.data[random.randint(0, len(self.data) - 1)]
                sound2, label2 = self.data[random.randint(0, len(self.data) - 1)]
                if label1 != label2:
                    break
            sound1 = self.preprocess(sound1)
            sound2 = self.preprocess(sound2)

            # Mix two examples
            r = np.array(random.random())
            sound = U.mix(sound1, sound2, r, self.opt.sr).astype(np.float32)
            # print(f"sound length after U.mix is {len(sound)}")
            # print(f"nClasses:{self.opt.nClasses}, type of mapdict:{type(self.mapdict)}, type of label1:{type(label1)}")
            eye = np.eye(self.opt.nClasses)
            idx1 = self.mapdict[str(label1)]- 1
            idx2 = self.mapdict[str(label2)] - 1
            label = (eye[idx1] * r + eye[idx2] * (1 - r)).astype(np.float32)
            # label = (eye[label1] * r + eye[label2] * (1 - r)).astype(np.float32)

            #For stronger augmentation
            sound = U.random_gain(6)(sound).astype(np.float32)
            # print(f"sound length after U.random_gain is {len(sound)}")
            sounds.append(sound);
            labels.append(label);

        sounds = np.asarray(sounds);
        labels = np.asarray(labels);
        # print(f"batchIndex is {batchIndex}, total sounds is {len(sounds)}")
        # print(f"labels in generate_batch is:\n{labels}")
        return sounds, labels;


    def generate_batch_select_fixed_class(self, batchIndex):
        #Generates data containing batch_size samples
        sounds = [];
        labels = [];
        indexes = None;
        #two variables recording alarm and moaning sounds count
        alarm_selected = 0;
        moaning_selected = 0;
        help_eng_selected = 0;
        for i in range(self.batch_size):
            # Training phase of BC learning
            # Select two training examples
            while True:
                # print("enter while true")
                sound1, label1 = self.data[random.randint(0, len(self.data) - 1)]
                sound2, label2 = self.data[random.randint(0, len(self.data) - 1)]
                lbl1_int = np.int16(label1);
                lbl2_int = np.int16(label2);
                # print(f"label1:{label1} and label2:{label2}")
                # print(f"label1:{type(label1)} and label2:{type(label2)}")
                if label1 != label2:
                    # print("enter first layer if");
                    if (lbl1_int == 52 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int ==52):
                        # print("enter 52 second layer if");
                        # if (alarm_selected < moaning_selected) or (alarm_selected == moaning_selected):
                        if (alarm_selected == moaning_selected) and (alarm_selected == help_eng_selected):
                            # print("enter 52 third layer if");
                            alarm_selected += 1;
                            # print(f"alarm sound selected, label1:{label1}, label2:{label2}, alarm_selected:{alarm_selected}, moaning_selected:{moaning_selected}");
                            # print("perform break at 52");
                            break;
                    if (lbl1_int == 56 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int == 56):
                        # print("enter 56 second layer if");
                        # if (moaning_selected < alarm_selected) or (alarm_selected == moaning_selected):
                        if (moaning_selected < alarm_selected) and (moaning_selected == help_eng_selected):
                            # print("enter 56 third layer if");
                            moaning_selected += 1;
                            # print(f"alarm sound selected, label1:{label1}, label2:{label2}, alarm_selected:{alarm_selected}, moaning_selected:{moaning_selected}");
                            # print("perform break at 56");
                            break;
                    if (lbl1_int == 71 and lbl2_int == 99) or (lbl1_int == 99 and lbl2_int == 71):
                        # print("enter 56 second layer if");
                        if (help_eng_selected < alarm_selected) and (help_eng_selected < moaning_selected):
                            # print("enter 56 third layer if");
                            moaning_selected += 1;
                            # print(f"alarm sound selected, label1:{label1}, label2:{label2}, alarm_selected:{alarm_selected}, moaning_selected:{moaning_selected}");
                            # print("perform break at 56");
                            break;
            # print(f"escape for loop");
            sound1 = self.preprocess(sound1)
            sound2 = self.preprocess(sound2)

            # Mix two examples
            r = np.array(random.random());
            #######make wanted class mix ration above 0.5##########
            # iLbl1 = np.int16(label1);
            # iLbl2 = np.int16(label2);
            # r = 1.0;
            # p_ratio1 = 0.4
            # p_ratio2 = 0.6
            # while True:
            #     r = np.array(random.random());
            #     if r > p_ratio1 and iLbl1 != 99 :
            #         break;
            #     if r < p_ratio2 and iLbl2 != 99 :
            #         break;
            #######################End#######################
            # print(f"r:{r}, lbl1:{label1}, lbl2:{label2}")  
            sound = U.mix(sound1, sound2, r, self.opt.sr).astype(np.float32)
            eye = np.eye(self.opt.nClasses)
            idx1 = self.mapdict[str(label1)]- 1
            idx2 = self.mapdict[str(label2)] - 1
            label = (eye[idx1] * r + eye[idx2] * (1 - r)).astype(np.float32)
            

            #For stronger augmentation
            sound = U.random_gain(6)(sound).astype(np.float32)
            # print(f"sound length after U.random_gain is {len(sound)}")
            sounds.append(sound);
            labels.append(label);

        sounds = np.asarray(sounds);
        labels = np.asarray(labels);
        # print(f"batchIndex is {batchIndex}, total sounds is {len(sounds)}")
        # print(f"labels in generate_batch is:\n{labels}")
        # print(f"alarm_selected:{alarm_selected}, moaning_selected:{moaning_selected}");
        return sounds, labels;

    def preprocess_setup(self):
        funcs = []
        if self.opt.strongAugment:
            funcs += [U.random_scale(1.25)]

        funcs += [U.padding(self.opt.inputLength // 2),
                  U.random_crop(self.opt.inputLength),
                  U.normalize(32768.0)]
        return funcs

    def preprocess(self, sound):
        for f in self.preprocess_funcs:
            sound = f(sound)

        return sound;

# %% [markdown]
# ## Define Trainer

# %%
class ReTrainer:
    def __init__(self, opt=None, classes_dict=None):
        self.opt = opt;
        self.testX = None;
        self.testY = None;
        self.bestAcc = 0.0;
        self.bestAccEpoch = 0;
        self.trainGen = getTrainGen(opt,classes_dict=classes_dict)#train_generator.setup(opt, split);
        # self.opt.trainer = self;
        # self.trainGen = getTrainGen(self.opt, self.opt.splits)#train_generator.setup(self.opt, self.opt.split);
        # self.pretrainedmodelpath = "./resources/pretrained_models/acdnet20_20khz_fold4.h5"

    def Train(self):
        train_start_time = time.time();
        # state = torch.load(second_pruned_model, map_location="cuda:0") //fidald
        state = torch.load(second_pruned_model, map_location="cpu") #home
        weights = state['weight']
        config = state['config']
        print(f"config is {config}")
        net = models.GetACDNetModel(input_len=30225, sr=20000, nclass=self.opt.nClasses, channel_config=config)
        net.load_state_dict(weights);
         #show the acdnet structures
        calc.summary(net,(1,1,30225))
        # net = getPrunedModel(pruned_model_path=pruned_acdnet)
        #print networks parameters' require_grade value
        for k_, v_ in net.named_parameters():
            print(f"{k_}:{v_.requires_grad}")
        print('ACDNet model has been prepared for training');

        calc.summary(net, (1,1,self.opt.inputLength));
        # net = net.cuda();
        # training_text = "Re-Training" if self.opt.retrain else "Training from Scratch";
        # print("{} has been started. You will see update after finishing every training epoch and validation".format(training_text));

        lossFunc = torch.nn.KLDivLoss(reduction='batchmean');
        optimizer = optim.SGD(net.parameters(), lr=self.opt.LR, weight_decay=self.opt.weightDecay, momentum=self.opt.momentum, nesterov=True);

        # self.opt.nEpochs = 1957 if self.opt.split == 4 else 2000;
        for epochIdx in range(self.opt.nEpochs):
            epoch_start_time = time.time();
            optimizer.param_groups[0]['lr'] = self.__get_lr(epochIdx+1);
            cur_lr = optimizer.param_groups[0]['lr'];
            running_loss = 0.0;
            running_acc = 0.0;
            n_batches = math.ceil(len(self.trainGen.data)/self.opt.batchSize);
            for batchIdx in range(n_batches):
                # with torch.no_grad():
                x,y = self.trainGen.__getitem__(batchIdx)
                x = torch.tensor(np.moveaxis(x, 3, 1)).to(self.opt.device);
                y = torch.tensor(y).to(self.opt.device);
                # zero the parameter gradients
                optimizer.zero_grad();

                # forward + backward + optimize
                # outputs = net(x);#in office and use cpu
                x = x.type(torch.FloatTensor) #use apple m2
                outputs = net(x)
                # in office use cpu, need to change to cuda
                # running_acc += (((outputs.data.argmax(dim=1) == y.argmax(dim=1))*1).float().mean()).item();
                # at home use apple m2
                res_y = y.argmax(dim=1)
                res_y = res_y.type(torch.FloatTensor)
                running_acc += ((( outputs.data.argmax(dim=1) == res_y)*1).float().mean()).item();
                y = y.type(torch.FloatTensor)
                
                loss = lossFunc(outputs.log(), y);
                loss.backward();
                optimizer.step();

                running_loss += loss.item();

            tr_acc = (running_acc / n_batches)*100;
            tr_loss = running_loss / n_batches;

            #Epoch wise validation Validation
            epoch_train_time = time.time() - epoch_start_time;

            net.eval();
            val_acc, val_loss = self.__validate(net, lossFunc);
            #Save best model
            # self.__save_model(val_acc, epochIdx, net);
            self.__save_model_v2(val_acc, tr_acc, epochIdx, net);
            self.__on_epoch_end(epoch_start_time, epoch_train_time, epochIdx, cur_lr, tr_loss, tr_acc, val_loss, val_acc);

            running_loss = 0;
            running_acc = 0;
            net.train();

        total_time_taken = time.time() - train_start_time;
        print("Execution finished in: {}".format(U.to_hms(total_time_taken)));

    def load_test_data(self):
        # data = np.load(os.path.join(self.opt.data, self.opt.dataset, 'test_data_{}khz/fold{}_test4000.npz'.format(self.opt.sr//1000, self.opt.split)), allow_pickle=True);
        data = np.load(self.opt.valData, allow_pickle=True);
        print(f"device is :{self.opt.device}")
        print(f"len of Y:{len(data['y'])}")
        # self.testX = torch.tensor(np.moveaxis(data['x'], 3, 1)).to(self.opt.device);
        dataX = np.moveaxis(data['x'], 3, 1).astype(np.float32);
        self.testX = torch.tensor(dataX).to(self.opt.device);
        self.testY = torch.tensor(data['y']).type(torch.float32).to(self.opt.device);

    def __get_lr(self, epoch):
        divide_epoch = np.array([self.opt.nEpochs * i for i in self.opt.schedule]);
        decay = sum(epoch > divide_epoch);
        if epoch <= self.opt.warmup:
            decay = 1;
        return self.opt.LR * np.power(0.1, decay);

    def __get_batch(self, index):
        x = self.trainX[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        y = self.trainY[index*self.opt.batchSize : (index+1)*self.opt.batchSize];
        return x.to(self.opt.device), y.to(self.opt.device);

    def __validate(self, net, lossFunc):
        if self.testX is None:
            self.load_test_data();
        net.eval();
        with torch.no_grad():
            y_pred = None;
            batch_size = len(self.testX);#(self.opt.batchSize//self.opt.nCrops)*self.opt.nCrops;
#             for idx in range(math.ceil(len(self.testX)/batch_size)):
#             for idx in range(len(self.testX)):
#             x = self.testX[idx*batch_size : (idx+1)*batch_size];
            x = self.testX[:];
            x = torch.tensor(x)
            x = x.type(torch.FloatTensor) # use apple mp2
            scores = net(x);
            y_pred = scores.data if y_pred is None else torch.cat((y_pred, scores.data));
            acc, loss = self.__compute_accuracy(y_pred, self.testY, lossFunc);
        net.train();
        return acc, loss;

    #Calculating average prediction (10 crops) and final accuracy
    def __compute_accuracy(self, y_pred, y_target, lossFunc):
        print(f"shape of y_pred:{y_pred.shape}");
        print(f"shape of y_target:{y_target.shape}");
        
        with torch.no_grad():
            #Reshape to shape theme like each sample comtains 10 samples, calculate mean and find theindices that has highest average value for each sample
            if self.opt.nCrops == 1:
                y_pred = y_pred.argmax(dim=1);
                y_target = y_target.argmax(dim=1);
            else:
                y_pred = (y_pred.reshape(y_pred.shape[0]//self.opt.nCrops, self.opt.nCrops, y_pred.shape[1])).mean(dim=1).argmax(dim=1);
                y_target = (y_target.reshape(y_target.shape[0]//self.opt.nCrops, self.opt.nCrops, y_target.shape[1])).mean(dim=1).argmax(dim=1);
                print(f"after: len of y_pred:{len(y_pred)}, len of y_target:{len(y_target)}")
            y_target = y_target.cpu() #use apple m2, in office use cuda
            acc = (((y_pred==y_target)*1).float().mean()*100).item();
            # valLossFunc = torch.nn.KLDivLoss();
            loss = lossFunc(y_pred.float().log(), y_target.float()).item();
            # loss = 0.0;
        return acc, loss;

    def __on_epoch_end(self, start_time, train_time, epochIdx, lr, tr_loss, tr_acc, val_loss, val_acc):
        epoch_time = time.time() - start_time;
        val_time = epoch_time - train_time;
        line = 'SP-{} Epoch: {}/{} | Time: {} (Train {}  Val {}) | Train: LR {}  Loss {:.2f}  Acc {:.2f}% | Val: Loss {:.2f}  Acc(top1) {:.2f}% | HA {:.2f}@{}\n'.format(
            self.opt.splits, epochIdx+1, self.opt.nEpochs, U.to_hms(epoch_time), U.to_hms(train_time), U.to_hms(val_time),
            lr, tr_loss, tr_acc, val_loss, val_acc, self.bestAcc, self.bestAccEpoch);
        # print(line)
        sys.stdout.write(line);
        sys.stdout.flush();

    # def __save_model(self, acc, epochIdx, net):
    #     if acc > self.bestAcc:
    #         self.bestAcc = acc;
    #         self.bestAccEpoch = epochIdx +1;
    #         save_model_name = self.opt.model_name.format(self.opt.pruningRatio*100,acc, epochIdx, genDataTimeStr());
    #         save_model_fullpath = self.opt.saveDir + save_model_name;
    #         print(f"save model to {save_model_fullpath}")
    #         torch.save({'weight':net.state_dict(), 'config':net.ch_config}, save_model_fullpath);

    def __save_model_v2(self, acc, train_acc, epochIdx, net):
        if acc > self.bestAcc and acc > self.opt.first_save_acc:
            self.bestAcc = acc;
            self.bestAccEpoch = epochIdx +1;
            self.__do_save_model(self.opt.pruningRatio*100, acc, train_acc, epochIdx, net);
        else:
            if acc > self.opt.save_val_acc and train_acc > self.opt.save_train_acc: 
                self.__do_save_model(self.opt.pruningRatio*100, acc, train_acc, epochIdx, net);
            else:
                pass

    def __do_save_model(self, ratio, acc, tr_acc, epochIdx, net):
        save_model_name = self.opt.model_name.format(ratio, acc, tr_acc, epochIdx+1, genDataTimeStr());
        save_model_fullpath = self.opt.saveDir + save_model_name;
        print(f"save model to {save_model_fullpath}")
        torch.save({'weight':net.state_dict(), 'config':net.ch_config}, save_model_fullpath);
        # logObj.write(f"save model:{self.opt.model_name}, bestAcc:{self.bestAcc}, valAcc:{acc}, trainAcc:{tr_acc}, record@{epochIdx}-epoch");
        # logObj.write("\n");
        # logObj.flush();

# %%
def getTrainGen(opt=None, split=None, classes_dict=None):
    dataset = np.load(opt.trainData, allow_pickle=True);
    train_sounds = []
    train_labels = []
    train_sounds = dataset['fold{}'.format(1)].item()['sounds']
    train_labels = dataset['fold{}'.format(1)].item()['labels']
    trainGen = TLGenerator(train_sounds, train_labels, opt, classes_dict=classes_dict);
    trainGen.preprocess_setup();
    return trainGen

# %%
""" recording training settings and results
===================================
weight-pruning-ratio:
final acc:93.03
epoch:539
opt.batchSize = 32;
opt.LR = 0.05;
opt.weightDecay = 5e-3;
opt.momentum = 0.04;
opt.nEpochs = 1000;
opt.schedule = [0.15, 0.3, 0.45];
opt.warmup = 10;
====================================================================
###針對二次剪枝後的重訓練，這個設定滿有效果的，要實驗是哪個參數造成的效果。
epoch:293
acc:89.4
tr_acc:76.4
opt.batchSize = 64;
opt.LR = 0.1;
opt.weightDecay = 5e-3;
opt.momentum = 0.5;
opt.nEpochs = 500;
opt.schedule = [0.3, 0.6, 0.9];
====================================================================
epoch:
acc:
tr_acc:
opt.batchSize = 64;
opt.LR = 0.1;
opt.weightDecay = 5e-4;
opt.momentum = 0.09;
opt.nEpochs = 800;
opt.schedule = [0.3, 0.6, 0.9];
opt.warmup = 10;
"""
# Out:
# ' recording training settings and results\n===================================\nweight-pruning-ratio:\nfinal acc:93.03\nepoch:539\nopt.batchSize = 32;\nopt.LR = 0.05;\nopt.weightDecay = 5e-3;\nopt.momentum = 0.04;\nopt.nEpochs = 1000;\nopt.schedule = [0.15, 0.3, 0.45];\nopt.warmup = 10;\n====================================================================\n###針對二次剪枝後的重訓練，這個設定滿有效果的，要實驗是哪個參數造成的效果。\nepoch:293\nacc:89.4\ntr_acc:76.4\nopt.batchSize = 64;\nopt.LR = 0.1;\nopt.weightDecay = 5e-3;\nopt.momentum = 0.5;\nopt.nEpochs = 500;\nopt.schedule = [0.3, 0.6, 0.9];\n====================================================================\nepoch:\nacc:\ntr_acc:\nopt.batchSize = 64;\nopt.LR = 0.1;\nopt.weightDecay = 5e-4;\nopt.momentum = 0.09;\nopt.nEpochs = 800;\nopt.schedule = [0.3, 0.6, 0.9];\nopt.warmup = 10;\n'

# %%
def main():
    map_dict_train = {
        '52':1, #alarm
        '56':2, #moaning
        '71':3,
        '99':4, #other_sounds
    };
    
    opt = getOpts();
    opt.pruningRatio = 0.85
    save_dir = "../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio{}_{}/".format(opt.pruningRatio,getDateStr());
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    print(f"save dir is: {save_dir}");
    opt.trainData = "../../../../uec_iot_ai_models_datasets/generated_datasets/train/version11/single_fold_train_20240603063535.npz"
    opt.valData = "../../../../uec_iot_ai_models_datasets/generated_datasets/val/version11/final_single_val_20240603063755.npz"
    #Leqarning settings
    opt.first_save_acc = 90.0;
    opt.save_val_acc = 90.0;
    opt.save_train_acc = 80.0;
    
    opt.batchSize = 64;
    opt.LR = 0.1;
    opt.weightDecay = 5e-4;
    opt.momentum = 0.9;
    opt.nEpochs = 1000;
    opt.schedule = [0.3, 0.6, 0.9];
    opt.warmup = 10;
    
    opt.saveDir = save_dir;
    # opt.device="mps";
    # if torch.backends.mps.is_available():
    #     opt.device="mps"; #for apple m2 gpu
    if torch.cuda.is_available():
        opt.device="cuda:0"; #for nVidia gpu
    else:
        opt.device="cpu"
    print(f"***Use device:{opt.device}");
    # opt.device = torch.device("cuda:0" if  else "cpu");
    #Basic Net Settings
    opt.nClasses = 4
    opt.nFolds = 1;
    opt.splits = [i for i in range(1, opt.nFolds + 1)];
    opt.sr = 20000;
    opt.inputLength = 30225;
    #Test data
    opt.nCrops = 2;
    opt.model_name = "retrained_4Cmodel_ratio{}_vaacc{}_tracc_{}@{}epoch_{}.pt"
    #Starting retraining process
    trainer = ReTrainer(opt=opt, classes_dict=map_dict_train);
    trainer.Train();

# %%
main()
# Out:
# save dir is: ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/
# ***Use device:cpu
# length of samples:1205
# config is [8, 32, 13, 25, 28, 32, 34, 36, 34, 28, 32, 4]
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (32, 1, 7553)      1,280    9,667,840
#   BatchNorm2d-5     (32, 1, 7553)     (32, 1, 7553)         64            0
#          ReLu-6     (32, 1, 7553)     (32, 1, 7553)          0      241,696
#     MaxPool2d-7     (32, 1, 7553)      (32, 1, 151)          0      241,600
#       Permute-8      (32, 1, 151)      (1, 32, 151)          0            0
#        Conv2d-9      (1, 32, 151)     (13, 32, 151)        117      565,344
#  BatchNorm2d-10     (13, 32, 151)     (13, 32, 151)         26            0
#         ReLu-11     (13, 32, 151)     (13, 32, 151)          0       62,816
#    MaxPool2d-12     (13, 32, 151)      (13, 16, 75)          0       62,400
#       Conv2d-13      (13, 16, 75)      (25, 16, 75)      2,925    3,510,000
#  BatchNorm2d-14      (25, 16, 75)      (25, 16, 75)         50            0
#         ReLu-15      (25, 16, 75)      (25, 16, 75)          0       30,000
#       Conv2d-16      (25, 16, 75)      (28, 16, 75)      6,300    7,560,000
#  BatchNorm2d-17      (28, 16, 75)      (28, 16, 75)         56            0
#         ReLu-18      (28, 16, 75)      (28, 16, 75)          0       33,600
#    MaxPool2d-19      (28, 16, 75)       (28, 8, 37)          0       33,152
#       Conv2d-20       (28, 8, 37)       (32, 8, 37)      8,064    2,386,944
#  BatchNorm2d-21       (32, 8, 37)       (32, 8, 37)         64            0
#         ReLu-22       (32, 8, 37)       (32, 8, 37)          0        9,472
#       Conv2d-23       (32, 8, 37)       (34, 8, 37)      9,792    2,898,432
#  BatchNorm2d-24       (34, 8, 37)       (34, 8, 37)         68            0
#         ReLu-25       (34, 8, 37)       (34, 8, 37)          0       10,064
#    MaxPool2d-26       (34, 8, 37)       (34, 4, 18)          0        9,792
#       Conv2d-27       (34, 4, 18)       (36, 4, 18)     11,016      793,152
#  BatchNorm2d-28       (36, 4, 18)       (36, 4, 18)         72            0
#         ReLu-29       (36, 4, 18)       (36, 4, 18)          0        2,592
#       Conv2d-30       (36, 4, 18)       (34, 4, 18)     11,016      793,152
#  BatchNorm2d-31       (34, 4, 18)       (34, 4, 18)         68            0
#         ReLu-32       (34, 4, 18)       (34, 4, 18)          0        2,448
#    MaxPool2d-33       (34, 4, 18)        (34, 2, 9)          0        2,448
#       Conv2d-34        (34, 2, 9)        (28, 2, 9)      8,568      154,224
#  BatchNorm2d-35        (28, 2, 9)        (28, 2, 9)         56            0
#         ReLu-36        (28, 2, 9)        (28, 2, 9)          0          504
#       Conv2d-37        (28, 2, 9)        (32, 2, 9)      8,064      145,152
#  BatchNorm2d-38        (32, 2, 9)        (32, 2, 9)         64            0
#         ReLu-39        (32, 2, 9)        (32, 2, 9)          0          576
#    MaxPool2d-40        (32, 2, 9)        (32, 1, 4)          0          512
#       Conv2d-41        (32, 1, 4)         (4, 1, 4)        128          512
#  BatchNorm2d-42         (4, 1, 4)         (4, 1, 4)          8            0
#         ReLu-43         (4, 1, 4)         (4, 1, 4)          0           16
#    AvgPool2d-44         (4, 1, 4)         (4, 1, 1)          0           16
#      Flatten-45         (4, 1, 1)            (1, 4)          0            0
#       Linear-46            (1, 4)            (1, 4)         20           20
#      Softmax-47            (1, 4)            (1, 4)          0            4
# ==============================================================================
# Total Params: 67,974
# Total FLOPs : 30,427,200
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 0.26
# Total size (MB) : 0.37
# ------------------------------------------------------------------------------
#
# sfeb.0.weight:True
# sfeb.1.weight:True
# sfeb.1.bias:True
# sfeb.3.weight:True
# sfeb.4.weight:True
# sfeb.4.bias:True
# tfeb.0.weight:True
# tfeb.1.weight:True
# tfeb.1.bias:True
# tfeb.4.weight:True
# tfeb.5.weight:True
# tfeb.5.bias:True
# tfeb.7.weight:True
# tfeb.8.weight:True
# tfeb.8.bias:True
# tfeb.11.weight:True
# tfeb.12.weight:True
# tfeb.12.bias:True
# tfeb.14.weight:True
# tfeb.15.weight:True
# tfeb.15.bias:True
# tfeb.18.weight:True
# tfeb.19.weight:True
# tfeb.19.bias:True
# tfeb.21.weight:True
# tfeb.22.weight:True
# tfeb.22.bias:True
# tfeb.25.weight:True
# tfeb.26.weight:True
# tfeb.26.bias:True
# tfeb.28.weight:True
# tfeb.29.weight:True
# tfeb.29.bias:True
# tfeb.33.weight:True
# tfeb.34.weight:True
# tfeb.34.bias:True
# tfeb.38.weight:True
# tfeb.38.bias:True
# ACDNet model has been prepared for training
# +----------------------------------------------------------------------------+
# +                           Pytorch Model Summary                            +
# ------------------------------------------------------------------------------
#    Layer (type)       Input Shape      Output Shape    Param #      FLOPS #
# ==============================================================================
#        Conv2d-1     (1, 1, 30225)     (8, 1, 15109)         72    1,087,848
#   BatchNorm2d-2     (8, 1, 15109)     (8, 1, 15109)         16            0
#          ReLu-3     (8, 1, 15109)     (8, 1, 15109)          0      120,872
#        Conv2d-4     (8, 1, 15109)     (32, 1, 7553)      1,280    9,667,840
#   BatchNorm2d-5     (32, 1, 7553)     (32, 1, 7553)         64            0
#          ReLu-6     (32, 1, 7553)     (32, 1, 7553)          0      241,696
#     MaxPool2d-7     (32, 1, 7553)      (32, 1, 151)          0      241,600
#       Permute-8      (32, 1, 151)      (1, 32, 151)          0            0
#        Conv2d-9      (1, 32, 151)     (13, 32, 151)        117      565,344
#  BatchNorm2d-10     (13, 32, 151)     (13, 32, 151)         26            0
#         ReLu-11     (13, 32, 151)     (13, 32, 151)          0       62,816
#    MaxPool2d-12     (13, 32, 151)      (13, 16, 75)          0       62,400
#       Conv2d-13      (13, 16, 75)      (25, 16, 75)      2,925    3,510,000
#  BatchNorm2d-14      (25, 16, 75)      (25, 16, 75)         50            0
#         ReLu-15      (25, 16, 75)      (25, 16, 75)          0       30,000
#       Conv2d-16      (25, 16, 75)      (28, 16, 75)      6,300    7,560,000
#  BatchNorm2d-17      (28, 16, 75)      (28, 16, 75)         56            0
#         ReLu-18      (28, 16, 75)      (28, 16, 75)          0       33,600
#    MaxPool2d-19      (28, 16, 75)       (28, 8, 37)          0       33,152
#       Conv2d-20       (28, 8, 37)       (32, 8, 37)      8,064    2,386,944
#  BatchNorm2d-21       (32, 8, 37)       (32, 8, 37)         64            0
#         ReLu-22       (32, 8, 37)       (32, 8, 37)          0        9,472
#       Conv2d-23       (32, 8, 37)       (34, 8, 37)      9,792    2,898,432
#  BatchNorm2d-24       (34, 8, 37)       (34, 8, 37)         68            0
#         ReLu-25       (34, 8, 37)       (34, 8, 37)          0       10,064
#    MaxPool2d-26       (34, 8, 37)       (34, 4, 18)          0        9,792
#       Conv2d-27       (34, 4, 18)       (36, 4, 18)     11,016      793,152
#  BatchNorm2d-28       (36, 4, 18)       (36, 4, 18)         72            0
#         ReLu-29       (36, 4, 18)       (36, 4, 18)          0        2,592
#       Conv2d-30       (36, 4, 18)       (34, 4, 18)     11,016      793,152
#  BatchNorm2d-31       (34, 4, 18)       (34, 4, 18)         68            0
#         ReLu-32       (34, 4, 18)       (34, 4, 18)          0        2,448
#    MaxPool2d-33       (34, 4, 18)        (34, 2, 9)          0        2,448
#       Conv2d-34        (34, 2, 9)        (28, 2, 9)      8,568      154,224
#  BatchNorm2d-35        (28, 2, 9)        (28, 2, 9)         56            0
#         ReLu-36        (28, 2, 9)        (28, 2, 9)          0          504
#       Conv2d-37        (28, 2, 9)        (32, 2, 9)      8,064      145,152
#  BatchNorm2d-38        (32, 2, 9)        (32, 2, 9)         64            0
#         ReLu-39        (32, 2, 9)        (32, 2, 9)          0          576
#    MaxPool2d-40        (32, 2, 9)        (32, 1, 4)          0          512
#       Conv2d-41        (32, 1, 4)         (4, 1, 4)        128          512
#  BatchNorm2d-42         (4, 1, 4)         (4, 1, 4)          8            0
#         ReLu-43         (4, 1, 4)         (4, 1, 4)          0           16
#    AvgPool2d-44         (4, 1, 4)         (4, 1, 1)          0           16
#      Flatten-45         (4, 1, 1)            (1, 4)          0            0
#       Linear-46            (1, 4)            (1, 4)         20           20
#      Softmax-47            (1, 4)            (1, 4)          0            4
# ==============================================================================
# Total Params: 67,974
# Total FLOPs : 30,427,200
# ------------------------------------------------------------------------------
# Input size (MB) : 0.12
# Params size (MB): 0.26
# Total size (MB) : 0.37
# ------------------------------------------------------------------------------
#
# device is :cpu
# len of Y:828
# /var/folders/m0/l8nfn78n58982dzcy33fh78c0000gn/T/ipykernel_1592/1339907207.py:125: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x)
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 1/1000 | Time: 0m17s (Train 0m13s  Val 0m03s) | Train: LR 0.010000000000000002  Loss 1.04  Acc 32.89% | Val: Loss 0.76  Acc(top1) 34.78% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 2/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.86  Acc 32.32% | Val: Loss nan  Acc(top1) 29.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 3/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.85  Acc 36.35% | Val: Loss nan  Acc(top1) 22.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 4/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.85  Acc 32.73% | Val: Loss nan  Acc(top1) 45.89% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 5/1000 | Time: 0m16s (Train 0m14s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.84  Acc 32.32% | Val: Loss nan  Acc(top1) 32.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 6/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.84  Acc 34.79% | Val: Loss nan  Acc(top1) 35.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 7/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.83  Acc 34.95% | Val: Loss nan  Acc(top1) 31.16% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 8/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.81  Acc 37.50% | Val: Loss nan  Acc(top1) 33.33% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 9/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.80  Acc 34.21% | Val: Loss nan  Acc(top1) 33.82% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 10/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.010000000000000002  Loss 0.80  Acc 38.08% | Val: Loss nan  Acc(top1) 31.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 11/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.86  Acc 31.91% | Val: Loss nan  Acc(top1) 45.17% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 12/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.85  Acc 32.73% | Val: Loss nan  Acc(top1) 35.27% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 13/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.86  Acc 31.58% | Val: Loss nan  Acc(top1) 26.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 14/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.79  Acc 38.90% | Val: Loss nan  Acc(top1) 39.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 15/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.77  Acc 43.17% | Val: Loss nan  Acc(top1) 37.92% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 16/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.77  Acc 41.53% | Val: Loss nan  Acc(top1) 42.03% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 17/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.71  Acc 47.12% | Val: Loss nan  Acc(top1) 61.59% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 18/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.72  Acc 50.90% | Val: Loss nan  Acc(top1) 44.69% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 19/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.73  Acc 47.78% | Val: Loss nan  Acc(top1) 62.08% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 20/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.71  Acc 45.72% | Val: Loss nan  Acc(top1) 55.31% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 21/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.69  Acc 50.82% | Val: Loss nan  Acc(top1) 37.68% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 22/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.70  Acc 48.11% | Val: Loss nan  Acc(top1) 49.76% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 23/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.71  Acc 49.10% | Val: Loss nan  Acc(top1) 27.78% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 24/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.68  Acc 51.56% | Val: Loss nan  Acc(top1) 44.69% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 25/1000 | Time: 0m14s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.68  Acc 51.89% | Val: Loss nan  Acc(top1) 38.41% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 26/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.68  Acc 53.95% | Val: Loss nan  Acc(top1) 67.63% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 27/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.68  Acc 54.69% | Val: Loss nan  Acc(top1) 44.93% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 28/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.64  Acc 54.11% | Val: Loss nan  Acc(top1) 52.66% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 29/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.64  Acc 53.70% | Val: Loss nan  Acc(top1) 51.93% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 30/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.65  Acc 54.19% | Val: Loss nan  Acc(top1) 45.65% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 31/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.66  Acc 55.35% | Val: Loss nan  Acc(top1) 70.29% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 32/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.62  Acc 55.51% | Val: Loss nan  Acc(top1) 43.00% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 33/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.62  Acc 55.35% | Val: Loss nan  Acc(top1) 66.43% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 34/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.61  Acc 55.51% | Val: Loss nan  Acc(top1) 57.25% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 35/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.61  Acc 58.80% | Val: Loss nan  Acc(top1) 69.08% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 36/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.61  Acc 59.38% | Val: Loss nan  Acc(top1) 61.59% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 37/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.61  Acc 56.50% | Val: Loss nan  Acc(top1) 65.94% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 38/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.66  Acc 53.87% | Val: Loss nan  Acc(top1) 50.48% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 39/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.59  Acc 60.94% | Val: Loss nan  Acc(top1) 44.93% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 40/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.20% | Val: Loss nan  Acc(top1) 49.28% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 41/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.60  Acc 58.63% | Val: Loss nan  Acc(top1) 72.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 42/1000 | Time: 0m15s (Train 0m13s  Val 0m02s) | Train: LR 0.1  Loss 0.60  Acc 57.81% | Val: Loss nan  Acc(top1) 62.32% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 43/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 59.13% | Val: Loss nan  Acc(top1) 68.12% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 44/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.20% | Val: Loss nan  Acc(top1) 66.18% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 45/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.20% | Val: Loss nan  Acc(top1) 63.29% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 46/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 58.72% | Val: Loss nan  Acc(top1) 72.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 47/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 59.70% | Val: Loss nan  Acc(top1) 73.19% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 48/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.60  Acc 58.72% | Val: Loss nan  Acc(top1) 59.18% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 49/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.59  Acc 60.61% | Val: Loss nan  Acc(top1) 46.62% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 50/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 62.34% | Val: Loss nan  Acc(top1) 65.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 51/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.57  Acc 63.40% | Val: Loss nan  Acc(top1) 77.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 52/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 62.58% | Val: Loss nan  Acc(top1) 81.88% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 53/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.58  Acc 59.87% | Val: Loss nan  Acc(top1) 62.08% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 54/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 61.60% | Val: Loss nan  Acc(top1) 76.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 55/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 64.56% | Val: Loss nan  Acc(top1) 65.70% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 56/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 65.13% | Val: Loss nan  Acc(top1) 74.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 57/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.57  Acc 59.13% | Val: Loss nan  Acc(top1) 78.02% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 58/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.57  Acc 60.61% | Val: Loss nan  Acc(top1) 70.53% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 59/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 62.42% | Val: Loss nan  Acc(top1) 64.49% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 60/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 64.39% | Val: Loss nan  Acc(top1) 71.98% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 61/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 63.98% | Val: Loss nan  Acc(top1) 63.77% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 62/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 65.38% | Val: Loss nan  Acc(top1) 72.22% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 63/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 62.58% | Val: Loss nan  Acc(top1) 74.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 64/1000 | Time: 0m19s (Train 0m13s  Val 0m05s) | Train: LR 0.1  Loss 0.53  Acc 64.80% | Val: Loss nan  Acc(top1) 84.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 65/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.55  Acc 64.31% | Val: Loss nan  Acc(top1) 42.27% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 66/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 64.80% | Val: Loss nan  Acc(top1) 71.01% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 67/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.56  Acc 62.99% | Val: Loss nan  Acc(top1) 64.73% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 68/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 65.21% | Val: Loss nan  Acc(top1) 58.70% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 69/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 66.69% | Val: Loss nan  Acc(top1) 75.12% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 70/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 63.57% | Val: Loss nan  Acc(top1) 72.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 71/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 66.37% | Val: Loss nan  Acc(top1) 54.35% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 72/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 64.97% | Val: Loss nan  Acc(top1) 75.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 73/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.54  Acc 63.40% | Val: Loss nan  Acc(top1) 75.60% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 74/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 66.45% | Val: Loss nan  Acc(top1) 82.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 75/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 64.97% | Val: Loss nan  Acc(top1) 69.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 76/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 65.46% | Val: Loss nan  Acc(top1) 69.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 77/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 66.61% | Val: Loss nan  Acc(top1) 77.05% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 78/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 64.23% | Val: Loss nan  Acc(top1) 79.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 79/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 65.87% | Val: Loss nan  Acc(top1) 75.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 80/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 67.60% | Val: Loss nan  Acc(top1) 67.15% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 81/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 63.82% | Val: Loss nan  Acc(top1) 75.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 82/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.27% | Val: Loss nan  Acc(top1) 74.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 83/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.26% | Val: Loss nan  Acc(top1) 79.23% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 84/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 66.20% | Val: Loss nan  Acc(top1) 81.16% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 85/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 67.19% | Val: Loss nan  Acc(top1) 71.26% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 86/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.53  Acc 65.62% | Val: Loss nan  Acc(top1) 68.36% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 87/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 64.88% | Val: Loss nan  Acc(top1) 82.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 88/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 66.28% | Val: Loss nan  Acc(top1) 45.89% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 89/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 65.79% | Val: Loss nan  Acc(top1) 56.76% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 90/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.52  Acc 65.38% | Val: Loss nan  Acc(top1) 65.70% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 91/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 65.54% | Val: Loss nan  Acc(top1) 81.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 92/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 70.15% | Val: Loss nan  Acc(top1) 68.36% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 93/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 68.59% | Val: Loss nan  Acc(top1) 86.96% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 94/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.51  Acc 67.52% | Val: Loss nan  Acc(top1) 72.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 95/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.35% | Val: Loss nan  Acc(top1) 72.95% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 96/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.02% | Val: Loss nan  Acc(top1) 78.02% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 97/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 66.37% | Val: Loss nan  Acc(top1) 44.20% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 98/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.43% | Val: Loss nan  Acc(top1) 77.05% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 99/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.02% | Val: Loss nan  Acc(top1) 84.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 100/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.19% | Val: Loss nan  Acc(top1) 86.47% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 101/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.85% | Val: Loss nan  Acc(top1) 63.04% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 102/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.76% | Val: Loss nan  Acc(top1) 63.53% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 103/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 68.83% | Val: Loss nan  Acc(top1) 43.96% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 104/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 65.30% | Val: Loss nan  Acc(top1) 70.53% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 105/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.68% | Val: Loss nan  Acc(top1) 61.84% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 106/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 69.57% | Val: Loss nan  Acc(top1) 82.13% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 107/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.11% | Val: Loss nan  Acc(top1) 40.10% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 108/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 68.42% | Val: Loss nan  Acc(top1) 85.02% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 109/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.46  Acc 66.86% | Val: Loss nan  Acc(top1) 84.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 110/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.11% | Val: Loss nan  Acc(top1) 82.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 111/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 68.01% | Val: Loss nan  Acc(top1) 65.46% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 112/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.93% | Val: Loss nan  Acc(top1) 79.71% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 113/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.46  Acc 68.34% | Val: Loss nan  Acc(top1) 55.80% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 114/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.85% | Val: Loss nan  Acc(top1) 64.73% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 115/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 68.67% | Val: Loss nan  Acc(top1) 80.43% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 116/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 65.62% | Val: Loss nan  Acc(top1) 74.40% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 117/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 66.53% | Val: Loss nan  Acc(top1) 73.67% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 118/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 68.09% | Val: Loss nan  Acc(top1) 76.57% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 119/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 67.52% | Val: Loss nan  Acc(top1) 81.88% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 120/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 70.07% | Val: Loss nan  Acc(top1) 67.39% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 121/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.45  Acc 71.30% | Val: Loss nan  Acc(top1) 77.54% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 122/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.50  Acc 67.93% | Val: Loss nan  Acc(top1) 82.61% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 123/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 68.34% | Val: Loss nan  Acc(top1) 79.47% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 124/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 70.15% | Val: Loss nan  Acc(top1) 63.29% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 125/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 68.26% | Val: Loss nan  Acc(top1) 73.43% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 126/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.45  Acc 70.31% | Val: Loss nan  Acc(top1) 81.64% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 127/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.44  Acc 70.23% | Val: Loss nan  Acc(top1) 80.43% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 128/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.60% | Val: Loss nan  Acc(top1) 81.64% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 129/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.60% | Val: Loss nan  Acc(top1) 85.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 130/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 67.76% | Val: Loss nan  Acc(top1) 72.22% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 131/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.47  Acc 68.01% | Val: Loss nan  Acc(top1) 47.58% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 132/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 68.50% | Val: Loss nan  Acc(top1) 85.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 133/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.46  Acc 70.72% | Val: Loss nan  Acc(top1) 78.50% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 134/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.44  Acc 71.05% | Val: Loss nan  Acc(top1) 87.44% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 135/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.46  Acc 69.41% | Val: Loss nan  Acc(top1) 85.99% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 136/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.46  Acc 69.98% | Val: Loss nan  Acc(top1) 84.06% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 137/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.43  Acc 73.11% | Val: Loss nan  Acc(top1) 82.85% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 138/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.45  Acc 71.38% | Val: Loss nan  Acc(top1) 48.31% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 139/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.48  Acc 69.41% | Val: Loss nan  Acc(top1) 64.98% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 140/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.49  Acc 69.00% | Val: Loss nan  Acc(top1) 63.04% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# SP-[1] Epoch: 141/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.1  Loss 0.45  Acc 69.65% | Val: Loss nan  Acc(top1) 70.05% | HA 0.00@0
# shape of y_pred:torch.Size([828, 4])
# ...
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_82.89473684210526@970epoch_20240604235625.pt
# SP-[1] Epoch: 970/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 82.89% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.75362396240234_tracc_80.42763157894737@971epoch_20240604235640.pt
# SP-[1] Epoch: 971/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 80.43% | Val: Loss nan  Acc(top1) 92.75% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.99516296386719_tracc_82.23684210526315@972epoch_20240604235656.pt
# SP-[1] Epoch: 972/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 82.24% | Val: Loss nan  Acc(top1) 93.00% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.2367172241211_tracc_82.8125@973epoch_20240604235711.pt
# SP-[1] Epoch: 973/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.81% | Val: Loss nan  Acc(top1) 93.24% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.2367172241211_tracc_82.1546052631579@974epoch_20240604235726.pt
# SP-[1] Epoch: 974/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.27  Acc 82.15% | Val: Loss nan  Acc(top1) 93.24% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.71980285644531_tracc_83.4703947368421@975epoch_20240604235742.pt
# SP-[1] Epoch: 975/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 83.47% | Val: Loss nan  Acc(top1) 93.72% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.96134948730469_tracc_82.31907894736842@976epoch_20240604235757.pt
# SP-[1] Epoch: 976/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.32% | Val: Loss nan  Acc(top1) 93.96% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.71980285644531_tracc_82.89473684210526@977epoch_20240604235812.pt
# SP-[1] Epoch: 977/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 82.89% | Val: Loss nan  Acc(top1) 93.72% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_83.05921052631578@978epoch_20240604235828.pt
# SP-[1] Epoch: 978/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 83.06% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.75362396240234_tracc_82.48355263157895@979epoch_20240604235843.pt
# SP-[1] Epoch: 979/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 82.48% | Val: Loss nan  Acc(top1) 92.75% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.99516296386719_tracc_81.74342105263158@980epoch_20240604235858.pt
# SP-[1] Epoch: 980/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 81.74% | Val: Loss nan  Acc(top1) 93.00% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.71980285644531_tracc_83.05921052631578@981epoch_20240604235913.pt
# SP-[1] Epoch: 981/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 83.06% | Val: Loss nan  Acc(top1) 93.72% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.75362396240234_tracc_85.60855263157895@982epoch_20240604235929.pt
# SP-[1] Epoch: 982/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 85.61% | Val: Loss nan  Acc(top1) 92.75% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.96134948730469_tracc_82.64802631578947@983epoch_20240604235944.pt
# SP-[1] Epoch: 983/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 82.65% | Val: Loss nan  Acc(top1) 93.96% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.99516296386719_tracc_82.48355263157895@984epoch_20240604235959.pt
# SP-[1] Epoch: 984/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 82.48% | Val: Loss nan  Acc(top1) 93.00% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.96134948730469_tracc_84.04605263157895@985epoch_20240605000015.pt
# SP-[1] Epoch: 985/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 84.05% | Val: Loss nan  Acc(top1) 93.96% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.96134948730469_tracc_81.82565789473685@986epoch_20240605000030.pt
# SP-[1] Epoch: 986/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 81.83% | Val: Loss nan  Acc(top1) 93.96% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.71980285644531_tracc_83.55263157894737@987epoch_20240605000045.pt
# SP-[1] Epoch: 987/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 83.55% | Val: Loss nan  Acc(top1) 93.72% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_82.23684210526315@988epoch_20240605000101.pt
# SP-[1] Epoch: 988/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 82.24% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_81.49671052631578@989epoch_20240605000116.pt
# SP-[1] Epoch: 989/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 81.50% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_82.97697368421053@990epoch_20240605000131.pt
# SP-[1] Epoch: 990/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.98% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.71980285644531_tracc_84.21052631578947@991epoch_20240605000147.pt
# SP-[1] Epoch: 991/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 84.21% | Val: Loss nan  Acc(top1) 93.72% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_81.16776315789474@992epoch_20240605000202.pt
# SP-[1] Epoch: 992/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 81.17% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.2367172241211_tracc_80.50986842105263@993epoch_20240605000217.pt
# SP-[1] Epoch: 993/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 80.51% | Val: Loss nan  Acc(top1) 93.24% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.2367172241211_tracc_81.82565789473685@994epoch_20240605000233.pt
# SP-[1] Epoch: 994/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 81.83% | Val: Loss nan  Acc(top1) 93.24% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc94.20289611816406_tracc_82.1546052631579@995epoch_20240605000248.pt
# SP-[1] Epoch: 995/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.15% | Val: Loss nan  Acc(top1) 94.20% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.51207733154297_tracc_80.3453947368421@996epoch_20240605000303.pt
# SP-[1] Epoch: 996/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.26  Acc 80.35% | Val: Loss nan  Acc(top1) 92.51% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_82.64802631578947@997epoch_20240605000319.pt
# SP-[1] Epoch: 997/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.65% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_82.07236842105263@998epoch_20240605000334.pt
# SP-[1] Epoch: 998/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 82.07% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc92.99516296386719_tracc_83.7171052631579@999epoch_20240605000349.pt
# SP-[1] Epoch: 999/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.24  Acc 83.72% | Val: Loss nan  Acc(top1) 93.00% | HA 94.44@500
# shape of y_pred:torch.Size([828, 4])
# shape of y_target:torch.Size([828, 4])
# after: len of y_pred:414, len of y_target:414
# save model to ../../../trained_models/step_5_retrain_after_step_4/retrain_4C_after_2nd_pruning_prunratio0.85_2024060419/retrained_4Cmodel_ratio85.0_vaacc93.47826385498047_tracc_83.4703947368421@1000epoch_20240605000405.pt
# SP-[1] Epoch: 1000/1000 | Time: 0m15s (Train 0m13s  Val 0m01s) | Train: LR 0.00010000000000000003  Loss 0.25  Acc 83.47% | Val: Loss nan  Acc(top1) 93.48% | HA 94.44@500
# Execution finished in: 4h15m
